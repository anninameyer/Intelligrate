# %% [markdown]
# # Extrapolate end-to-end (intelligrate.extrapolate)
#
# This notebook runs the full `intelligrate.extrapolate` workflow using the **Python API**:
# 1) nested CV training (OOF outputs)
# 2) full fit (final model artifact)
# 3) full predict (new samples + optional evaluation on paired subset)
#
# Outputs are written to `results/`.
#
# It uses the example data in `data/`.

# %% [markdown]
# ## Install (pip)
# If you are running this notebook outside the repo, install with pip.

# %%
from pathlib import Path
import sys
import json
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# '/Users/meyeanni/Desktop/git_sourdough/Intelligrate/docs/notebooks'

# %% [markdown]
# install intelligrate (if not yet installed):

# %%
# Uncomment if needed:
# !pip install "intelligrate @ git+https://github.com/ORG/REPO.git@vX.Y.Z"

# %%
def find_repo_root(start: Path) -> Path:
    for p in [start, *start.parents]:
        if (p / 'pyproject.toml').exists():
            return p
    raise FileNotFoundError('Could not find repo root (pyproject.toml)')

repo_root = find_repo_root(Path.cwd())

# Ensure local package imports work without installation
sys.path.insert(0, str(repo_root / 'src'))

results_dir = repo_root / 'results/primates_ecs'
results_dir.mkdir(parents=True, exist_ok=True)

print('Repo root:', repo_root)
print('Results dir:', results_dir)
# Out:
# Repo root: /Users/meyeanni/Desktop/git_sourdough/Intelligrate
# Results dir: /Users/meyeanni/Desktop/git_sourdough/Intelligrate/results/primates_ecs

# %% [markdown]
# ## Load inputs
# - `X_ASVs.tsv`: paired samples (ASVs)
# - `X_ASVs_full.tsv`: all samples (paired + unpaired, for extrapolation)
# - `Y_kos.tsv`: KO profiles for paired samples
# - `ko_to_superclass.tsv`: KO -> pathway/superclass mapping, optional

# %%
X_full = pd.read_csv(repo_root / 'data/primates' / 'X_ASVs_full.tsv', sep='	', index_col=0)
X = pd.read_csv(repo_root / 'data/primates' / 'X_ASVs.tsv', sep='	', index_col=0)
Y = pd.read_csv(repo_root / 'data/primates' / 'Y_ecs.tsv', sep='	', index_col=0)

X_full = X_full.apply(pd.to_numeric, errors="coerce")
X = X.apply(pd.to_numeric, errors="coerce")
Y = Y.apply(pd.to_numeric, errors="coerce")

print('X_full:', X_full.shape)
print('X:', X.shape)
print('Y:', Y.shape)
# Out:
# X_full: (77, 8251)
# X: (77, 8251)
# Y: (77, 2468)

# %% [markdown]
# ### Optional: Pre-filter Y before any modeling
# If you want to pre-filter KO features (e.g., apply a detection threshold once globally and keep zeroes as informative), do it here **once** and then use `Y` everywhere downstream.
# This avoids per-fold KO dropping, but it changes the modeling assumptions.
#
# **Important:** if you do this, pass the filtered `Y` into all downstream calls (training, fixed-param sweep, evaluation, PICRUSt2 comparisons).

# %%
# --- Optional global Y pre-filtering (edit as needed) ---
# Example: apply a detect threshold once and keep zeros as zeros.
# This is global pre-filtering; be aware this uses all samples (no CV isolation).
# If you enable this, replace Y with Y_prefiltered and use it everywhere downstream.
#
# detect_threshold = model_cfg['y_detect_threshold']
# Y_prefiltered = Y.copy()
# Y_prefiltered = Y_prefiltered.mask(Y_prefiltered < detect_threshold, 0.0)
# Y = Y_prefiltered

# NOTE: After this point, make sure any call uses the updated Y:
# - train/_run_once or nested CV inputs
# - fixed_param_oof_knn_on_embedding
# - evaluate_paired_subset
# - PICRUSt2 comparisons (align to the same KO set as Y)

# %% [markdown]
# ## Parameters
# Parameters that we define here correspond to what can be found in the **defaults** as `configs/default.yaml`, but now we expose them here in the notebook for easier editing.
#
#
# If you want to see every parameter and full explanations, also check:
# - `docs/TUTORIAL_extrapolate.md`
# - `src/intelligrate/extrapolate/train.py` and `src/intelligrate/extrapolate/cv_knn.py`

# %%
# ---- Data file names (used by the training API) ----
data_cfg = {
    'x_full': 'X_ASVs_full.tsv',
    'x': 'X_ASVs.tsv',
    'y': 'Y_ecs.tsv',
    'picrust2': 'picrust2_ecs.tsv', # optional for comparison
    #'ko_to_superclass':   # optional mapping file
}


# ---- Cross-validation settings ----
cv_cfg = {
    # outer_splits/inner_splits: more splits = slower but more stable estimates
    'outer_splits': 5,
    'inner_splits': 3,
    'seed': 0,
    # informed_splits: use metadata to form splits (False by default)
    'informed_splits': False,
}

# ---- X embedding (k-mer -> low-dim) ----
embed_cfg = {
    # min_prev_x_abs: drop k-mers present in fewer samples than this
    'min_prev_x_abs': 16,
    # pseudocount_x: added before CLR
    'pseudocount_x': 0.5,
    # n_components: SVD dimensions for the k-mer embedding (X space)
    'n_components': 16, #10
}

# ---- Model / prediction settings ----
model_cfg = {
    # min_prev_y_abs: drop KOs seen in fewer samples than this
    'min_prev_y_abs': 1,
    # y_detect_threshold: detection threshold in TSS space
    'y_detect_threshold': 1000.0,
    # pseudocount_y: added before CLR
    'pseudocount_y': 0.5 / 1e6,

    # KNN hyperparameters (grid for nested CV)
    'neigh_k_grid': [20, 24, 28, 32],
    'tau_mult_grid': [0.5, 1.0, 2.0, 4.0],
    'lam_grid': [0.0],
    'y_latent_k_grid': [0, 10, 20],

    # Metric learning
    'use_metric_learning': True,
    'metric_max_pairs': 5000,
    'metric_ridge_grid': [1.0, 2.5, 5.0],

    # Out-of-distribution shrinkage
    'ood_shrink': True,
    'ood_shrink_inner': True,
    'ood_lam_base': 0.7,
    'ood_lam_cap': 0.5,
    'ood_tau_inflate': False,
}

# ---- Objective weights ----
objective_cfg = {
    # w_dm is the primary objective (Aitchison DM Spearman)
    'w_dm': 1.0,
    'w_wclr': 0.0,
    'w_pw_rmse': 0.0,
    'w_softf1': 0.0,
    'w_jsd': 0.0,
}

# ---- Precision/recall settings ----
prf_cfg = {
    'prf_thresh': 1.0e-6,
    'prf_weight': 'binary', 
}

# ---- Optional metrics ----
metrics_cfg = {
    'compute_wclr': True,
    'compute_jsd': True, 
    'compute_pathway_rmse': False,
    'pathway_rmse_per_group': False,
    'pathway_rmse_log1p': False,
}

# ---- Score settings (for the optional global OOF DM check) ----
score_cfg = {
    'min_prev_y_abs': 1,
    'y_detect_threshold': 3000.0,
    'pseudocount_y': 0.5 / 1e6,
}

# %% [markdown]
# ## 1) Train on paired-samples (nested CV)
# We call the training API directly and then write the outputs to `results/`.
#
# This step is to get out-of-fold (OOF) predictions for the paired samples, which can be used for initial model evaluation and calibration/hyperparameter tuning and selection.

# %%
from intelligrate.extrapolate import train as train_model

cfg = {
    'data': data_cfg,
    'cv': cv_cfg,
    'embed': embed_cfg,
    'model': model_cfg,
    'objective': objective_cfg,
    'prf': prf_cfg,
    'metrics': metrics_cfg,
    'score': score_cfg,
}

payload = train_model._run_once(cfg, data_dir=repo_root / 'data/primates', out_dir=results_dir)

# Write outputs (same files as the CLI)
oof_clr = payload['oof_clr']
oof_tss = payload['oof_tss']
folds = payload['folds']
run = payload['run']

# Save core outputs
(oof_clr).to_csv(results_dir / 'oof_clr.tsv', sep='	')
(oof_tss).to_csv(results_dir / 'oof_tss.tsv', sep='	')
folds.to_csv(results_dir / 'folds.tsv', sep='	', index=False)
(results_dir / 'summary.json').write_text(json.dumps(run, indent=2))

summary_flat = {k: v for k, v in run.items() if k != 'config'}
pd.DataFrame([summary_flat]).to_csv(results_dir / 'summary.tsv', sep='	', index=False)

print('OBJECTIVE_DM_SPEARMAN_MEAN:', run['objective_dm_spearman_mean'])
print('MODEL_DM_UNION_STRICT:', run['model_dm_union_strict'])
# Out:
# OBJECTIVE_DM_SPEARMAN_MEAN: 0.5455116762966628
# MODEL_DM_UNION_STRICT: 0.8674177249575088

# %%
summary = json.loads((results_dir / 'summary.json').read_text())
summary_keys = [
    'objective_dm_spearman_mean',
    'model_dm_union_strict',
    'picrust2_dm_union_strict',
    'delta_union',
    'runtime_sec',
]

pd.DataFrame([{k: summary.get(k) for k in summary_keys}])
# Out:
#    objective_dm_spearman_mean  model_dm_union_strict  \
# 0                    0.545512               0.867418
#
#    picrust2_dm_union_strict  delta_union  runtime_sec
# 0                  0.887025    -0.019607     2.722137

# %% [markdown]
#   - objective_dm_spearman_mean: primary training objective, averaged Spearman correlation between true vs. predicted
#   Aitchison distance matrices across CV folds (higher = better recovery of sample–sample structure).
#   - model_dm_union_strict: KO‑union Spearman score on OOF predictions (union of KOs in truth and prediction, computed in CLR/
#   Aitchison space; higher = better overall agreement).
#   - picrust2_dm_union_strict: same KO‑union score for PICRUSt2 (baseline), optional (only if PICRUSt2 predictions are provided).
#   - delta_union: model_dm_union_strict − picrust2_dm_union_strict (positive means the model beats PICRUSt2 in terms of matrix spearman correlations on the KO union).
#   - runtime_sec: total training runtime in seconds.

# %%
folds = pd.read_csv(results_dir / 'folds.tsv', sep='	')
folds.head()
# Out:
#    fold split_mode  kmeans_k_used  best_inner_comp  best_inner_dm  \
# 0     1      kfold            NaN         0.288764       0.381963
# 1     2      kfold            NaN         0.296596       0.373916
# 2     3      kfold            NaN         0.387875       0.407783
# 3     4      kfold            NaN         0.349265       0.386322
# 4     5      kfold            NaN         0.432587       0.525903
#
#    dm_spearman  wclr_mse  pw_rmse_log1p  soft_precision  soft_recall  ...  \
# 0     0.593958  0.540152            NaN        0.998340     0.999447  ...
# 1     0.591645  0.369413            NaN        0.996243     1.000000  ...
# 2     0.347045  0.495495            NaN        0.995028     1.000000  ...
# 3     0.579038  0.336744            NaN        0.996557     1.000000  ...
# 4     0.615872  0.150382            NaN        1.000000     1.000000  ...
#
#    shrink_lam_q90  std_dm_true  std_dm_pred  y_keep_n  neigh_k  tau_mult  lam  \
# 0             0.5     2.723536     0.933219       339       20       0.5  0.0
# 1             0.5     1.922161     0.907520       366       28       0.5  0.0
# 2             0.5     2.677005     0.541665       362       20       1.0  0.0
# 3             0.5     2.280780     1.146003       368       24       0.5  0.0
# 4             0.5     2.590838     1.301207       354       20       0.5  0.0
#
#    y_latent_k  metric_ridge  inner_dm
# 0          10           1.0  0.381963
# 1          10           1.0  0.373916
# 2          10           1.0  0.407783
# 3          10           1.0  0.386322
# 4          20           1.0  0.525903
#
# [5 rows x 27 columns]

# %% [markdown]
# -->> this contains all the 'best' parameter selections for paired sample predictions, which can be considered for evaluation and calibration/hyperparameter tuning and selection.

# %%
#how many rows in oof_tss contain any nans?:
oof_tss.isna().any(axis=1).sum()
# Out:
# np.int64(77)

# %% [markdown]
# -> all these nans need to be addressed in the evaluations further below

# %% [markdown]
# ### Optional: fixed-parameter sweep for stable hyperparameters
#
# Use this to find a **single fixed hyperparameter set** that performs well for leakage-free OOF.
# It evaluates each combo with fixed-parameter OOF and ranks by `dm_union_strict`.
#
# **Important:** if a parameter is *not* listed in `fixed_param_sweep`, the sweep will use the value
# from config. For parameters with a `*_grid` (e.g., `neigh_k_grid`), it will use that grid list.
# To force a single value, list it explicitly in `fixed_param_sweep`.

# %% [markdown]
# for (otpional) pathway evaluation later on, we import also the KO -> pathway mapping:

# %%
#make a dictionary out of ko to superclass mapping:
# ko_to_superclass_path = repo_root / 'data/primates_ecs' / 'ko_to_superclass.tsv'
# ko_to_superclass_df = pd.read_csv(ko_to_superclass_path, sep='	', index_col=0)
# ko_to_superclass = ko_to_superclass_df['superclass'].to_dict()
# ko_to_superclass
# Out:
# {'K00001': 'SCFA fermentation',
#  'K00002': 'Cofactors/vitamins',
#  'K00003': 'Energy/central carbon',
#  'K00004': 'Energy/central carbon',
#  'K00005': 'Energy/central carbon',
#  'K00008': 'Energy/central carbon',
#  'K00009': 'Energy/central carbon',
#  'K00010': 'Energy/central carbon',
#  'K00012': 'Carbohydrate metabolism',
#  'K00013': 'Energy/central carbon',
#  'K00014': 'Tryptophan metabolism',
#  'K00015': 'Energy/central carbon',
#  'K00016': 'SCFA fermentation',
#  'K00018': 'Energy/central carbon',
#  'K00019': 'Other',
#  'K00020': 'Energy/central carbon',
#  'K00024': 'Energy/central carbon',
#  'K00026': 'Energy/central carbon',
#  'K00027': 'Energy/central carbon',
#  'K00029': 'Energy/central carbon',
#  'K00030': 'Cofactors/vitamins',
#  'K00031': 'Other',
#  'K00032': 'Energy/central carbon',
#  'K00033': 'Energy/central carbon',
#  'K00034': 'Energy/central carbon',
#  'K00036': 'Energy/central carbon',
#  'K00038': 'Energy/central carbon',
#  'K00040': 'Energy/central carbon',
#  'K00041': 'Energy/central carbon',
#  'K00042': 'Energy/central carbon',
#  'K00045': 'Carbohydrate metabolism',
#  'K00046': 'Energy/central carbon',
#  'K00052': 'Other',
#  'K00053': 'Energy/central carbon',
#  'K00054': 'Energy/central carbon',
#  'K00055': 'Energy/central carbon',
#  'K00057': 'Cofactors/vitamins',
#  'K00058': 'Energy/central carbon',
#  'K00059': 'Lipid metabolism',
#  'K00060': 'Amino acid metabolism',
#  'K00065': 'Energy/central carbon',
#  'K00067': 'Energy/central carbon',
#  'K00068': 'Energy/central carbon',
#  'K00073': 'Cofactors/vitamins',
#  'K00074': 'Energy/central carbon',
#  'K00075': 'Cell envelope/biogenesis',
#  'K00077': 'Energy/central carbon',
#  'K00086': 'Energy/central carbon',
#  'K00087': 'Carbohydrate metabolism',
#  'K00088': 'Energy/central carbon',
#  'K00090': 'Energy/central carbon',
#  'K00091': 'Energy/central carbon',
#  'K00094': 'Carbohydrate metabolism',
#  'K00096': 'Cofactors/vitamins',
#  'K00097': 'Other',
#  'K00098': 'Other',
#  'K00099': 'Energy/central carbon',
#  'K00101': 'SCFA fermentation',
#  'K00102': 'SCFA fermentation',
#  'K00104': 'Cofactors/vitamins',
#  'K00105': 'Energy/central carbon',
#  'K00108': 'Carbohydrate metabolism',
#  'K00111': 'Energy/central carbon',
#  'K00112': 'Other',
#  'K00113': 'Other',
#  'K00114': 'Cofactors/vitamins',
#  'K00116': 'Energy/central carbon',
#  'K00117': 'Carbohydrate metabolism',
#  'K00121': 'Energy/central carbon',
#  'K00122': 'SCFA fermentation',
#  'K00123': 'Antibiotic resistance/efflux',
#  'K00124': 'Transport',
#  'K00127': 'SCFA fermentation',
#  'K00128': 'Cofactors/vitamins',
#  'K00130': 'Transport',
#  'K00131': 'Energy/central carbon',
#  'K00133': 'Amino acid metabolism',
#  'K00134': 'Energy/central carbon',
#  'K00135': 'Synaptic pathways',
#  'K00138': 'Transcriptional regulation',
#  'K00140': 'Energy/central carbon',
#  'K00145': 'Energy/central carbon',
#  'K00146': 'Other',
#  'K00147': 'Amino acid metabolism',
#  'K00148': 'Amino acid metabolism',
#  'K00154': 'Transcriptional regulation',
#  'K00156': 'SCFA fermentation',
#  'K00158': 'Energy/central carbon',
#  'K00161': 'Energy/central carbon',
#  'K00162': 'Energy/central carbon',
#  'K00163': 'Energy/central carbon',
#  'K00164': 'Energy/central carbon',
#  'K00166': 'Other',
#  'K00167': 'Other',
#  'K00169': 'Energy/central carbon',
#  'K00184': 'Transport',
#  'K00185': 'Transport',
#  'K00196': 'Energy/central carbon',
#  'K00208': 'Lipid metabolism',
#  'K00209': 'Cofactors/vitamins',
#  'K00215': 'Energy/central carbon',
#  'K00216': 'Other',
#  'K00218': 'Other',
#  'K00220': 'Tryptophan metabolism',
#  'K00226': 'Energy/central carbon',
#  'K00228': 'Energy/central carbon',
#  'K00230': 'Cofactors/vitamins',
#  'K00239': 'Energy/central carbon',
#  'K00240': 'Energy/central carbon',
#  'K00241': 'Energy/central carbon',
#  'K00242': 'Transport',
#  'K00243': 'Other',
#  'K00244': 'Energy/central carbon',
#  'K00245': 'Energy/central carbon',
#  'K00246': 'Energy/central carbon',
#  'K00247': 'Energy/central carbon',
#  'K00248': 'Energy/central carbon',
#  'K00249': 'Energy/central carbon',
#  'K00254': 'Energy/central carbon',
#  'K00259': 'Amino acid metabolism',
#  'K00262': 'Energy/central carbon',
#  'K00265': 'Energy/central carbon',
#  'K00266': 'Energy/central carbon',
#  'K00274': 'Synaptic pathways',
#  'K00275': 'Energy/central carbon',
#  'K00276': 'Energy/central carbon',
#  'K00278': 'Amino acid metabolism',
#  'K00281': 'Amino acid metabolism',
#  'K00283': 'Amino acid metabolism',
#  'K00284': 'Amino acid metabolism',
#  'K00285': 'Amino acid metabolism',
#  'K00286': 'Energy/central carbon',
#  'K00287': 'Energy/central carbon',
#  'K00297': 'Cofactors/vitamins',
#  'K00298': 'Amino acid metabolism',
#  'K00299': 'Cofactors/vitamins',
#  'K00301': 'Energy/central carbon',
#  'K00304': 'Energy/central carbon',
#  'K00305': 'Energy/central carbon',
#  'K00311': 'Energy/central carbon',
#  'K00316': 'Transport',
#  'K00322': 'Cofactors/vitamins',
#  'K00324': 'Cofactors/vitamins',
#  'K00325': 'Cofactors/vitamins',
#  'K00326': 'Cofactors/vitamins',
#  'K00330': 'Energy/central carbon',
#  'K00331': 'Energy/central carbon',
#  'K00332': 'Energy/central carbon',
#  'K00333': 'Energy/central carbon',
#  'K00334': 'Energy/central carbon',
#  'K00335': 'Energy/central carbon',
#  'K00336': 'Energy/central carbon',
#  'K00337': 'Energy/central carbon',
#  'K00338': 'Energy/central carbon',
#  'K00339': 'Energy/central carbon',
#  'K00340': 'Energy/central carbon',
#  'K00341': 'Energy/central carbon',
#  'K00342': 'Energy/central carbon',
#  'K00343': 'Energy/central carbon',
#  'K00344': 'Cofactors/vitamins',
#  'K00346': 'Transport',
#  'K00347': 'Transport',
#  'K00348': 'Transport',
#  'K00349': 'Transport',
#  'K00350': 'Transport',
#  'K00354': 'Other',
#  'K00355': 'Cofactors/vitamins',
#  'K00362': 'Energy/central carbon',
#  'K00363': 'Energy/central carbon',
#  'K00364': 'Energy/central carbon',
#  'K00366': 'Energy/central carbon',
#  'K00370': 'Energy/central carbon',
#  'K00371': 'Energy/central carbon',
#  'K00372': 'Cofactors/vitamins',
#  'K00373': 'Cofactors/vitamins',
#  'K00374': 'Energy/central carbon',
#  'K00375': 'Transcriptional regulation',
#  'K00380': 'Energy/central carbon',
#  'K00381': 'Cofactors/vitamins',
#  'K00382': 'Energy/central carbon',
#  'K00383': 'Amino acid metabolism',
#  'K00384': 'Cofactors/vitamins',
#  'K00389': 'Transport',
#  'K00390': 'Other',
#  'K00410': 'Cofactors/vitamins',
#  'K00411': 'Cofactors/vitamins',
#  'K00412': 'Cofactors/vitamins',
#  'K00413': 'Cofactors/vitamins',
#  'K00424': 'Cofactors/vitamins',
#  'K00425': 'Cofactors/vitamins',
#  'K00426': 'Cofactors/vitamins',
#  'K00427': 'SCFA fermentation',
#  'K00428': 'Energy/central carbon',
#  'K00432': 'Energy/central carbon',
#  'K00433': 'Cofactors/vitamins',
#  'K00435': 'Cofactors/vitamins',
#  'K00459': 'Cofactors/vitamins',
#  'K00467': 'SCFA fermentation',
#  'K00483': 'Tryptophan metabolism',
#  'K00484': 'Cofactors/vitamins',
#  'K00520': 'Transcriptional regulation',
#  'K00523': 'Carbohydrate metabolism',
#  'K00525': 'Energy/central carbon',
#  'K00526': 'Energy/central carbon',
#  'K00527': 'Energy/central carbon',
#  'K00528': 'Transcriptional regulation',
#  'K00537': 'Energy/central carbon',
#  'K00547': 'Carbohydrate metabolism',
#  'K00548': 'Carbohydrate metabolism',
#  'K00549': 'Carbohydrate metabolism',
#  'K00554': 'RNA processing/degradation',
#  'K00556': 'RNA processing/degradation',
#  'K00557': 'RNA processing/degradation',
#  'K00558': 'DNA replication/repair/maintenance',
#  'K00560': 'Carbohydrate metabolism',
#  'K00563': 'RNA processing/degradation',
#  'K00564': 'RNA processing/degradation',
#  'K00566': 'RNA processing/degradation',
#  'K00567': 'Amino acid metabolism',
#  'K00568': 'Carbohydrate metabolism',
#  'K00569': 'RNA processing/degradation',
#  'K00570': 'RNA processing/degradation',
#  'K00571': 'DNA replication/repair/maintenance',
#  'K00573': 'Amino acid metabolism',
#  'K00574': 'Lipid metabolism',
#  'K00575': 'RNA processing/degradation',
#  'K00588': 'Carbohydrate metabolism',
#  'K00590': 'DNA replication/repair/maintenance',
#  'K00595': 'Carbohydrate metabolism',
#  'K00596': 'Energy/central carbon',
#  'K00598': 'RNA processing/degradation',
#  'K00600': 'Amino acid metabolism',
#  'K00602': 'Carbohydrate metabolism',
#  'K00604': 'RNA processing/degradation',
#  'K00605': 'Amino acid metabolism',
#  'K00606': 'Carbohydrate metabolism',
#  'K00609': 'Amino acid metabolism',
#  'K00610': 'Amino acid metabolism',
#  'K00611': 'Amino acid metabolism',
#  'K00615': 'Carbohydrate metabolism',
#  'K00616': 'Carbohydrate metabolism',
#  'K00620': 'Amino acid metabolism',
#  'K00625': 'SCFA fermentation',
#  'K00626': 'Carbohydrate metabolism',
#  'K00627': 'Energy/central carbon',
#  'K00631': 'Lipid metabolism',
#  'K00632': 'Carbohydrate metabolism',
#  'K00633': 'Carbohydrate metabolism',
#  'K00634': 'Other',
#  'K00638': 'Carbohydrate metabolism',
#  'K00639': 'Amino acid metabolism',
#  'K00640': 'Amino acid metabolism',
#  'K00641': 'Carbohydrate metabolism',
#  'K00643': 'Translation/ribosome',
#  'K00645': 'Lipid metabolism',
#  'K00647': 'Lipid metabolism',
#  'K00648': 'Lipid metabolism',
#  'K00651': 'Carbohydrate metabolism',
#  'K00652': 'Transport',
#  'K00654': 'Amino acid metabolism',
#  'K00655': 'Lipid metabolism',
#  'K00656': 'SCFA fermentation',
#  'K00657': 'Carbohydrate metabolism',
#  'K00658': 'Energy/central carbon',
#  'K00661': 'Carbohydrate metabolism',
#  'K00662': 'Carbohydrate metabolism',
#  'K00666': 'Energy/central carbon',
#  'K00673': 'Amino acid metabolism',
#  'K00674': 'Antibiotic resistance/efflux',
#  'K00675': 'Carbohydrate metabolism',
#  'K00677': 'Cell envelope/biogenesis',
#  'K00681': 'Amino acid metabolism',
#  'K00684': 'Translation/ribosome',
#  'K00687': 'Cell envelope/biogenesis',
#  'K00688': 'Carbohydrate metabolism',
#  'K00689': 'Other',
#  'K00690': 'Carbohydrate metabolism',
#  'K00691': 'Carbohydrate metabolism',
#  'K00692': 'Carbohydrate metabolism',
#  'K00694': 'Carbohydrate metabolism',
#  'K00697': 'Carbohydrate metabolism',
#  'K00700': 'Carbohydrate metabolism',
#  'K00702': 'Carbohydrate metabolism',
#  'K00703': 'Carbohydrate metabolism',
#  'K00705': 'Other',
#  'K00712': 'Carbohydrate metabolism',
#  'K00720': 'Carbohydrate metabolism',
#  'K00721': 'Carbohydrate metabolism',
#  'K00728': 'Carbohydrate metabolism',
#  'K00737': 'Carbohydrate metabolism',
#  'K00748': 'Lipid metabolism',
#  'K00754': 'Carbohydrate metabolism',
#  'K00756': 'Nucleotide metabolism',
#  'K00757': 'Carbohydrate metabolism',
#  'K00758': 'Carbohydrate metabolism',
#  'K00759': 'Carbohydrate metabolism',
#  'K00760': 'Carbohydrate metabolism',
#  'K00761': 'RNA processing/degradation',
#  'K00762': 'Carbohydrate metabolism',
#  'K00763': 'Translation/ribosome',
#  'K00764': 'Carbohydrate metabolism',
#  'K00765': 'Carbohydrate metabolism',
#  'K00766': 'Tryptophan metabolism',
#  'K00767': 'Nucleotide metabolism',
#  'K00768': 'Nucleotide metabolism',
#  'K00769': 'Carbohydrate metabolism',
#  'K00772': 'Carbohydrate metabolism',
#  'K00773': 'RNA processing/degradation',
#  'K00782': 'SCFA fermentation',
#  'K00783': 'RNA processing/degradation',
#  'K00784': 'Translation/ribosome',
#  'K00786': 'Carbohydrate metabolism',
#  'K00788': 'Cofactors/vitamins',
#  'K00789': 'Carbohydrate metabolism',
#  'K00790': 'Cell envelope/biogenesis',
#  'K00791': 'RNA processing/degradation',
#  'K00793': 'Cofactors/vitamins',
#  'K00794': 'Carbohydrate metabolism',
#  'K00795': 'Carbohydrate metabolism',
#  'K00796': 'Carbohydrate metabolism',
#  'K00797': 'Transport',
#  'K00798': 'Carbohydrate metabolism',
#  'K00799': 'Carbohydrate metabolism',
#  'K00800': 'Carbohydrate metabolism',
#  'K00801': 'Carbohydrate metabolism',
#  'K00805': 'Carbohydrate metabolism',
#  'K00806': 'Carbohydrate metabolism',
#  'K00812': 'Amino acid metabolism',
#  'K00813': 'Amino acid metabolism',
#  'K00817': 'Carbohydrate metabolism',
#  'K00820': 'Carbohydrate metabolism',
#  'K00821': 'Carbohydrate metabolism',
#  'K00822': 'Carbohydrate metabolism',
#  'K00823': 'SCFA fermentation',
#  'K00824': 'Amino acid metabolism',
#  'K00826': 'Carbohydrate metabolism',
#  'K00830': 'Amino acid metabolism',
#  'K00831': 'Carbohydrate metabolism',
#  'K00832': 'Tryptophan metabolism',
#  'K00833': 'Carbohydrate metabolism',
#  'K00835': 'Carbohydrate metabolism',
#  'K00836': 'Carbohydrate metabolism',
#  'K00839': 'Carbohydrate metabolism',
#  'K00840': 'Carbohydrate metabolism',
#  'K00841': 'Carbohydrate metabolism',
#  'K00845': 'Carbohydrate metabolism',
#  'K00846': 'Other',
#  'K00847': 'Carbohydrate metabolism',
#  'K00848': 'Other',
#  'K00849': 'Carbohydrate metabolism',
#  'K00850': 'Carbohydrate metabolism',
#  'K00851': 'Carbohydrate metabolism',
#  'K00852': 'Carbohydrate metabolism',
#  'K00853': 'Carbohydrate metabolism',
#  'K00854': 'Carbohydrate metabolism',
#  'K00855': 'Other',
#  'K00857': 'Carbohydrate metabolism',
#  'K00858': 'Cofactors/vitamins',
#  'K00859': 'Carbohydrate metabolism',
#  'K00860': 'Carbohydrate metabolism',
#  'K00863': 'Cofactors/vitamins',
#  'K00864': 'Carbohydrate metabolism',
#  'K00865': 'Carbohydrate metabolism',
#  'K00867': 'Carbohydrate metabolism',
#  'K00868': 'Cofactors/vitamins',
#  'K00869': 'Lipid metabolism',
#  'K00872': 'Carbohydrate metabolism',
#  'K00873': 'Carbohydrate metabolism',
#  'K00874': 'Carbohydrate metabolism',
#  'K00876': 'Carbohydrate metabolism',
#  'K00878': 'Carbohydrate metabolism',
#  'K00880': 'Carbohydrate metabolism',
#  'K00882': 'Carbohydrate metabolism',
#  'K00883': 'Energy/central carbon',
#  'K00884': 'Carbohydrate metabolism',
#  'K00887': 'Carbohydrate metabolism',
#  'K00891': 'Tryptophan metabolism',
#  'K00892': 'Other',
#  'K00899': 'Other',
#  'K00901': 'Carbohydrate metabolism',
#  'K00906': 'Carbohydrate metabolism',
#  'K00912': 'Other',
#  'K00917': 'Other',
#  'K00919': 'Carbohydrate metabolism',
#  'K00925': 'SCFA fermentation',
#  'K00926': 'Carbohydrate metabolism',
#  'K00927': 'Carbohydrate metabolism',
#  'K00928': 'Amino acid metabolism',
#  'K00929': 'SCFA fermentation',
#  'K00930': 'Carbohydrate metabolism',
#  'K00931': 'Amino acid metabolism',
#  'K00932': 'Carbohydrate metabolism',
#  'K00936': 'Signal transduction',
#  'K00937': 'Carbohydrate metabolism',
#  'K00938': 'Carbohydrate metabolism',
#  'K00939': 'Carbohydrate metabolism',
#  'K00940': 'Nucleotide metabolism',
#  'K00941': 'Carbohydrate metabolism',
#  'K00942': 'Carbohydrate metabolism',
#  'K00943': 'Carbohydrate metabolism',
#  'K00945': 'Carbohydrate metabolism',
#  'K00946': 'Cofactors/vitamins',
#  'K00948': 'Carbohydrate metabolism',
#  'K00949': 'Cofactors/vitamins',
#  'K00950': 'Carbohydrate metabolism',
#  'K00951': 'Signal transduction',
#  'K00954': 'Carbohydrate metabolism',
#  'K00955': 'Carbohydrate metabolism',
#  'K00956': 'Carbohydrate metabolism',
#  'K00957': 'Carbohydrate metabolism',
#  'K00958': 'Carbohydrate metabolism',
#  'K00962': 'RNA processing/degradation',
#  'K00963': 'RNA processing/degradation',
#  'K00965': 'Carbohydrate metabolism',
#  'K00968': 'Carbohydrate metabolism',
#  'K00969': 'Nucleotide metabolism',
#  'K00970': 'DNA replication/repair/maintenance',
#  'K00971': 'Carbohydrate metabolism',
#  'K00973': 'Carbohydrate metabolism',
#  'K00974': 'RNA processing/degradation',
#  'K00975': 'Carbohydrate metabolism',
#  'K00979': 'Carbohydrate metabolism',
#  'K00980': 'Carbohydrate metabolism',
#  'K00981': 'Carbohydrate metabolism',
#  'K00982': 'Tryptophan metabolism',
#  'K00984': 'Antibiotic resistance/efflux',
#  'K00986': 'DNA replication/repair/maintenance',
#  'K00989': 'Translation/ribosome',
#  'K00990': 'Carbohydrate metabolism',
#  'K00991': 'Carbohydrate metabolism',
#  'K00992': 'Carbohydrate metabolism',
#  'K00995': 'Carbohydrate metabolism',
#  'K00997': 'Lipid metabolism',
#  'K00998': 'Carbohydrate metabolism',
#  'K01000': 'Carbohydrate metabolism',
#  'K01002': 'Other',
#  'K01006': 'Carbohydrate metabolism',
#  'K01007': 'Carbohydrate metabolism',
#  'K01008': 'Carbohydrate metabolism',
#  'K01011': 'RNA processing/degradation',
#  'K01012': 'Cofactors/vitamins',
#  'K01023': 'Carbohydrate metabolism',
#  'K01026': 'Carbohydrate metabolism',
#  'K01029': 'Carbohydrate metabolism',
#  'K01042': 'RNA processing/degradation',
#  'K01048': 'Other',
#  'K01049': 'Synaptic pathways',
#  'K01050': 'Other',
#  'K01051': 'Other',
#  'K01053': 'Other',
#  'K01056': 'RNA processing/degradation',
#  'K01057': 'Carbohydrate metabolism',
#  'K01058': 'Carbohydrate metabolism',
#  'K01061': 'Other',
#  'K01066': 'Carbohydrate metabolism',
#  'K01067': 'Carbohydrate metabolism',
#  'K01069': 'Other',
#  'K01070': 'Carbohydrate metabolism',
#  'K01071': 'Lipid metabolism',
#  'K01073': 'Carbohydrate metabolism',
#  'K01075': 'Carbohydrate metabolism',
#  'K01077': 'Carbohydrate metabolism',
#  'K01079': 'Carbohydrate metabolism',
#  'K01081': 'Carbohydrate metabolism',
#  'K01082': 'Nucleotide metabolism',
#  'K01085': 'Carbohydrate metabolism',
#  'K01087': 'Carbohydrate metabolism',
#  'K01089': 'Energy/central carbon',
#  'K01090': 'Carbohydrate metabolism',
#  'K01091': 'Carbohydrate metabolism',
#  'K01092': 'Carbohydrate metabolism',
#  'K01093': 'Carbohydrate metabolism',
#  'K01095': 'Carbohydrate metabolism',
#  'K01096': 'Carbohydrate metabolism',
#  'K01101': 'Carbohydrate metabolism',
#  'K01104': 'Tryptophan metabolism',
#  'K01113': 'Carbohydrate metabolism',
#  'K01114': 'Carbohydrate metabolism',
#  'K01118': 'Cofactors/vitamins',
#  'K01119': 'Nucleotide metabolism',
#  'K01120': 'Nucleotide metabolism',
#  'K01126': 'Carbohydrate metabolism',
#  'K01129': 'Other',
#  'K01133': 'Carbohydrate metabolism',
#  'K01139': 'Carbohydrate metabolism',
#  'K01141': 'DNA replication/repair/maintenance',
#  'K01142': 'DNA replication/repair/maintenance',
#  'K01146': 'Other',
#  'K01147': 'Carbohydrate metabolism',
#  'K01150': 'Carbohydrate metabolism',
#  'K01151': 'Carbohydrate metabolism',
#  'K01153': 'Defense systems',
#  'K01154': 'Defense systems',
#  'K01155': 'Defense systems',
#  'K01156': 'DNA replication/repair/maintenance',
#  'K01159': 'DNA replication/repair/maintenance',
#  'K01166': 'Translation/ribosome',
#  'K01169': 'RNA processing/degradation',
#  'K01173': 'Defense systems',
#  'K01175': 'Carbohydrate metabolism',
#  'K01176': 'Carbohydrate metabolism',
#  'K01178': 'Other',
#  'K01179': 'Other',
#  'K01181': 'Carbohydrate metabolism',
#  'K01182': 'Carbohydrate metabolism',
#  'K01183': 'Carbohydrate metabolism',
#  'K01185': 'Carbohydrate metabolism',
#  'K01187': 'Carbohydrate metabolism',
#  'K01188': 'Carbohydrate metabolism',
#  'K01190': 'Carbohydrate metabolism',
#  'K01191': 'Carbohydrate metabolism',
#  'K01193': 'Carbohydrate metabolism',
#  'K01194': 'Other',
#  'K01195': 'Carbohydrate metabolism',
#  'K01197': 'Carbohydrate metabolism',
#  'K01198': 'Carbohydrate metabolism',
#  'K01200': 'Carbohydrate metabolism',
#  'K01201': 'Carbohydrate metabolism',
#  'K01206': 'Other',
#  'K01207': 'Carbohydrate metabolism',
#  'K01208': 'Carbohydrate metabolism',
#  'K01209': 'Carbohydrate metabolism',
#  'K01212': 'Carbohydrate metabolism',
#  'K01214': 'Other',
#  'K01215': 'Carbohydrate metabolism',
#  'K01220': 'Carbohydrate metabolism',
#  'K01222': 'Carbohydrate metabolism',
#  'K01223': 'Carbohydrate metabolism',
#  'K01224': 'Cell envelope/biogenesis',
#  'K01226': 'Carbohydrate metabolism',
#  'K01227': 'Carbohydrate metabolism',
#  'K01232': 'Carbohydrate metabolism',
#  'K01233': 'Other',
#  'K01235': 'Carbohydrate metabolism',
#  'K01236': 'Other',
#  'K01237': 'Other',
#  'K01239': 'Nucleotide metabolism',
#  'K01241': 'Carbohydrate metabolism',
#  'K01243': 'Carbohydrate metabolism',
#  'K01246': 'DNA replication/repair/maintenance',
#  'K01247': 'DNA replication/repair/maintenance',
#  'K01250': 'Nucleotide metabolism',
#  'K01251': 'Other',
#  'K01252': 'Carbohydrate metabolism',
#  'K01255': 'Carbohydrate metabolism',
#  'K01256': 'Carbohydrate metabolism',
#  'K01258': 'Carbohydrate metabolism',
#  'K01259': 'Amino acid metabolism',
#  'K01261': 'Carbohydrate metabolism',
#  'K01262': 'Carbohydrate metabolism',
#  'K01265': 'Carbohydrate metabolism',
#  'K01266': 'Carbohydrate metabolism',
#  'K01269': 'Carbohydrate metabolism',
#  'K01270': 'Carbohydrate metabolism',
#  'K01271': 'Carbohydrate metabolism',
#  'K01273': 'Transport',
#  'K01274': 'Carbohydrate metabolism',
#  'K01278': 'Carbohydrate metabolism',
#  'K01281': 'Carbohydrate metabolism',
#  'K01284': 'Carbohydrate metabolism',
#  'K01286': 'Amino acid metabolism',
#  'K01295': 'Amino acid metabolism',
#  'K01297': 'Amino acid metabolism',
#  'K01299': 'Amino acid metabolism',
#  'K01303': 'Carbohydrate metabolism',
#  'K01304': 'Carbohydrate metabolism',
#  'K01305': 'Carbohydrate metabolism',
#  'K01318': 'Translation/ribosome',
#  'K01322': 'Energy/central carbon',
#  'K01338': 'Protein folding/quality control',
#  'K01347': 'Amino acid metabolism',
#  'K01354': 'Other',
#  'K01356': 'Signal transduction',
#  'K01358': 'Protein folding/quality control',
#  'K01361': 'Other',
#  'K01372': 'Carbohydrate metabolism',
#  'K01406': 'Other',
#  'K01407': 'Protein folding/quality control',
#  'K01409': 'Carbohydrate metabolism',
#  'K01414': 'Other',
#  'K01419': 'Protein folding/quality control',
#  'K01420': 'Transcriptional regulation',
#  'K01421': 'Transport',
#  'K01424': 'Carbohydrate metabolism',
#  'K01425': 'Other',
#  'K01426': 'Carbohydrate metabolism',
#  'K01428': 'Other',
#  'K01429': 'Other',
#  'K01430': 'Other',
#  'K01433': 'Carbohydrate metabolism',
#  'K01434': 'Amino acid metabolism',
#  'K01436': 'Other',
#  'K01438': 'Carbohydrate metabolism',
#  'K01439': 'Carbohydrate metabolism',
#  'K01442': 'Carbohydrate metabolism',
#  'K01443': 'Carbohydrate metabolism',
#  'K01444': 'Carbohydrate metabolism',
#  'K01447': 'Amino acid metabolism',
#  'K01448': 'Amino acid metabolism',
#  'K01451': 'Other',
#  'K01452': 'Carbohydrate metabolism',
#  'K01457': 'Other',
#  'K01458': 'Carbohydrate metabolism',
#  'K01460': 'Translation/ribosome',
#  'K01461': 'Transport',
#  'K01462': 'Carbohydrate metabolism',
#  'K01464': 'Other',
#  'K01465': 'Carbohydrate metabolism',
#  'K01466': 'Other',
#  'K01467': 'Antibiotic resistance/efflux',
#  'K01468': 'Other',
#  'K01470': 'Carbohydrate metabolism',
#  'K01473': 'Other',
#  'K01474': 'Other',
#  'K01476': 'Carbohydrate metabolism',
#  'K01478': 'Amino acid metabolism',
#  'K01479': 'Carbohydrate metabolism',
#  'K01480': 'Other',
#  'K01484': 'Other',
#  'K01485': 'Carbohydrate metabolism',
#  'K01486': 'Amino acid metabolism',
#  'K01487': 'Carbohydrate metabolism',
#  'K01488': 'Amino acid metabolism',
#  'K01489': 'Carbohydrate metabolism',
#  'K01491': 'Cofactors/vitamins',
#  'K01493': 'Carbohydrate metabolism',
#  'K01494': 'Carbohydrate metabolism',
#  'K01495': 'Carbohydrate metabolism',
#  'K01496': 'Carbohydrate metabolism',
#  'K01497': 'Carbohydrate metabolism',
#  'K01498': 'Energy/central carbon',
#  'K01502': 'Other',
#  'K01507': 'Carbohydrate metabolism',
#  'K01512': 'Carbohydrate metabolism',
#  'K01515': 'Carbohydrate metabolism',
#  'K01520': 'Carbohydrate metabolism',
#  'K01521': 'Carbohydrate metabolism',
#  'K01523': 'Carbohydrate metabolism',
#  'K01524': 'Carbohydrate metabolism',
#  'K01525': 'Other',
#  'K01531': 'Transport',
#  'K01533': 'Transport',
#  'K01534': 'Transport',
#  'K01535': 'Transport',
#  'K01537': 'Transport',
#  'K01546': 'Transport',
#  'K01547': 'Transport',
#  'K01548': 'Transport',
#  'K01551': 'Transport',
#  'K01560': 'Carbohydrate metabolism',
#  'K01563': 'Carbohydrate metabolism',
#  'K01568': 'Energy/central carbon',
#  'K01569': 'Energy/central carbon',
#  'K01571': 'Energy/central carbon',
#  'K01574': 'Energy/central carbon',
#  'K01575': 'Energy/central carbon',
#  'K01576': 'Energy/central carbon',
#  'K01577': 'Energy/central carbon',
#  'K01579': 'Amino acid metabolism',
#  'K01580': 'Synaptic pathways',
#  'K01581': 'Amino acid metabolism',
#  'K01582': 'Amino acid metabolism',
#  'K01584': 'Amino acid metabolism',
#  'K01585': 'Amino acid metabolism',
#  'K01586': 'Energy/central carbon',
#  'K01588': 'Energy/central carbon',
#  'K01589': 'Translation/ribosome',
#  'K01590': 'Amino acid metabolism',
#  'K01591': 'Energy/central carbon',
#  'K01595': 'Carbohydrate metabolism',
#  'K01597': 'Energy/central carbon',
#  'K01598': 'Energy/central carbon',
#  'K01599': 'Carbohydrate metabolism',
#  'K01607': 'Energy/central carbon',
#  'K01609': 'Tryptophan metabolism',
#  'K01610': 'Energy/central carbon',
#  'K01611': 'Carbohydrate metabolism',
#  'K01612': 'Energy/central carbon',
#  'K01613': 'Energy/central carbon',
#  'K01619': 'Energy/central carbon',
#  'K01620': 'Energy/central carbon',
#  'K01621': 'Energy/central carbon',
#  'K01623': 'Energy/central carbon',
#  'K01624': 'Energy/central carbon',
#  'K01625': 'Energy/central carbon',
#  'K01626': 'Carbohydrate metabolism',
#  'K01627': 'Energy/central carbon',
#  'K01628': 'Energy/central carbon',
#  'K01629': 'Energy/central carbon',
#  'K01630': 'Energy/central carbon',
#  'K01631': 'Energy/central carbon',
#  'K01633': 'Energy/central carbon',
#  'K01634': 'Energy/central carbon',
#  'K01635': 'Energy/central carbon',
#  'K01637': 'Other',
#  'K01638': 'Energy/central carbon',
#  'K01639': 'Energy/central carbon',
#  'K01641': 'Carbohydrate metabolism',
#  'K01643': 'Carbohydrate metabolism',
#  'K01644': 'Energy/central carbon',
#  'K01646': 'Carbohydrate metabolism',
#  'K01647': 'Carbohydrate metabolism',
#  'K01649': 'Other',
#  'K01652': 'Carbohydrate metabolism',
#  'K01653': 'Carbohydrate metabolism',
#  'K01657': 'Tryptophan metabolism',
#  'K01658': 'Tryptophan metabolism',
#  'K01659': 'Carbohydrate metabolism',
#  'K01661': 'Energy/central carbon',
#  'K01662': 'Carbohydrate metabolism',
#  'K01663': 'Energy/central carbon',
#  'K01664': 'Translation/ribosome',
#  'K01665': 'Translation/ribosome',
#  'K01669': 'Other',
#  'K01671': 'Energy/central carbon',
#  'K01673': 'Energy/central carbon',
#  'K01674': 'Energy/central carbon',
#  'K01676': 'Energy/central carbon',
#  'K01679': 'Energy/central carbon',
#  'K01681': 'Energy/central carbon',
#  'K01682': 'Energy/central carbon',
#  'K01684': 'Energy/central carbon',
#  'K01685': 'Other',
#  'K01686': 'Energy/central carbon',
#  'K01687': 'Energy/central carbon',
#  'K01689': 'Energy/central carbon',
#  'K01690': 'Energy/central carbon',
#  'K01692': 'Energy/central carbon',
#  'K01693': 'Energy/central carbon',
#  'K01695': 'Tryptophan metabolism',
#  'K01696': 'Tryptophan metabolism',
#  'K01697': 'Carbohydrate metabolism',
#  'K01698': 'Energy/central carbon',
#  'K01699': 'Energy/central carbon',
#  'K01703': 'Energy/central carbon',
#  'K01704': 'Energy/central carbon',
#  'K01706': 'Energy/central carbon',
#  'K01708': 'Energy/central carbon',
#  'K01710': 'Energy/central carbon',
#  'K01711': 'Energy/central carbon',
#  'K01712': 'Energy/central carbon',
#  'K01714': 'Energy/central carbon',
#  'K01715': 'Energy/central carbon',
#  'K01716': 'Lipid metabolism',
#  'K01719': 'Carbohydrate metabolism',
#  'K01720': 'Energy/central carbon',
#  'K01727': 'Other',
#  'K01733': 'Amino acid metabolism',
#  'K01734': 'Other',
#  'K01735': 'Energy/central carbon',
#  'K01736': 'Tryptophan metabolism',
#  'K01737': 'Energy/central carbon',
#  'K01738': 'Amino acid metabolism',
#  'K01739': 'Carbohydrate metabolism',
#  'K01740': 'Carbohydrate metabolism',
#  'K01744': 'Amino acid metabolism',
#  'K01745': 'Signal transduction',
#  'K01749': 'Carbohydrate metabolism',
#  'K01750': 'Amino acid metabolism',
#  'K01751': 'Energy/central carbon',
#  'K01752': 'Amino acid metabolism',
#  'K01753': 'Amino acid metabolism',
#  'K01754': 'Amino acid metabolism',
#  'K01755': 'Energy/central carbon',
#  'K01756': 'Energy/central carbon',
#  'K01758': 'Carbohydrate metabolism',
#  'K01759': 'Energy/central carbon',
#  'K01760': 'Amino acid metabolism',
#  'K01766': 'Amino acid metabolism',
#  'K01768': 'Carbohydrate metabolism',
#  'K01770': 'Carbohydrate metabolism',
#  'K01772': 'Energy/central carbon',
#  'K01775': 'Amino acid metabolism',
#  'K01776': 'Amino acid metabolism',
#  'K01777': 'Amino acid metabolism',
#  'K01778': 'Energy/central carbon',
#  'K01779': 'Amino acid metabolism',
#  'K01782': 'Energy/central carbon',
#  'K01783': 'Energy/central carbon',
#  'K01784': 'Energy/central carbon',
#  'K01785': 'Energy/central carbon',
#  'K01788': 'Energy/central carbon',
#  'K01790': 'Energy/central carbon',
#  'K01791': 'Energy/central carbon',
#  'K01792': 'Energy/central carbon',
#  'K01802': 'Energy/central carbon',
#  'K01803': 'Energy/central carbon',
#  'K01804': 'Energy/central carbon',
#  'K01805': 'Energy/central carbon',
#  'K01807': 'Energy/central carbon',
#  'K01808': 'Energy/central carbon',
#  'K01809': 'Energy/central carbon',
#  'K01810': 'Energy/central carbon',
#  'K01811': 'Carbohydrate metabolism',
#  'K01812': 'Energy/central carbon',
#  'K01813': 'Energy/central carbon',
#  'K01814': 'Energy/central carbon',
#  'K01815': 'Energy/central carbon',
#  'K01817': 'Tryptophan metabolism',
#  'K01818': 'Energy/central carbon',
#  'K01819': 'Carbohydrate metabolism',
#  'K01821': 'Energy/central carbon',
#  'K01823': 'Energy/central carbon',
#  'K01825': 'Energy/central carbon',
#  'K01829': 'Other',
#  'K01834': 'Energy/central carbon',
#  'K01835': 'Energy/central carbon',
#  'K01838': 'Energy/central carbon',
#  'K01839': 'Energy/central carbon',
#  'K01840': 'Other',
#  'K01843': 'Amino acid metabolism',
#  'K01845': 'Amino acid metabolism',
#  'K01851': 'Other',
#  'K01854': 'Energy/central carbon',
#  'K01856': 'Antibiotic resistance/efflux',
#  'K01857': 'Antibiotic resistance/efflux',
#  'K01866': 'Tryptophan metabolism',
#  'K01867': 'Tryptophan metabolism',
#  'K01868': 'Translation/ribosome',
#  'K01869': 'Translation/ribosome',
#  'K01870': 'Translation/ribosome',
#  'K01872': 'Translation/ribosome',
#  'K01873': 'Translation/ribosome',
#  'K01874': 'Translation/ribosome',
#  'K01875': 'Translation/ribosome',
#  'K01876': 'Translation/ribosome',
#  'K01878': 'Translation/ribosome',
#  'K01879': 'Translation/ribosome',
#  'K01881': 'Mobilome',
#  'K01883': 'Translation/ribosome',
#  'K01885': 'Translation/ribosome',
#  'K01886': 'Translation/ribosome',
#  'K01887': 'Translation/ribosome',
#  'K01889': 'Tryptophan metabolism',
#  'K01890': 'Tryptophan metabolism',
#  'K01892': 'Translation/ribosome',
#  'K01893': 'Translation/ribosome',
#  'K01894': 'Translation/ribosome',
#  'K01895': 'Translation/ribosome',
#  'K01897': 'Energy/central carbon',
#  'K01902': 'Carbohydrate metabolism',
#  'K01908': 'Translation/ribosome',
#  'K01910': 'Translation/ribosome',
#  'K01911': 'Translation/ribosome',
#  'K01912': 'Carbohydrate metabolism',
#  'K01914': 'Amino acid metabolism',
#  'K01915': 'Translation/ribosome',
#  'K01916': 'Cofactors/vitamins',
#  'K01918': 'Amino acid metabolism',
#  'K01919': 'Amino acid metabolism',
#  'K01920': 'Amino acid metabolism',
#  'K01921': 'Amino acid metabolism',
#  'K01923': 'Translation/ribosome',
#  'K01924': 'Cell envelope/biogenesis',
#  'K01925': 'Cell envelope/biogenesis',
#  'K01926': 'RNA processing/degradation',
#  'K01928': 'Cell envelope/biogenesis',
#  'K01929': 'Cell envelope/biogenesis',
#  'K01933': 'Translation/ribosome',
#  'K01934': 'Translation/ribosome',
#  'K01935': 'Translation/ribosome',
#  'K01937': 'Translation/ribosome',
#  'K01938': 'Translation/ribosome',
#  'K01939': 'Translation/ribosome',
#  'K01940': 'Translation/ribosome',
#  'K01941': 'Translation/ribosome',
#  'K01945': 'Amino acid metabolism',
#  'K01950': 'Translation/ribosome',
#  'K01951': 'Translation/ribosome',
#  'K01952': 'Translation/ribosome',
#  'K01953': 'Translation/ribosome',
#  'K01955': 'Translation/ribosome',
#  'K01956': 'Translation/ribosome',
#  'K01958': 'Translation/ribosome',
#  'K01961': 'Cofactors/vitamins',
#  'K01962': 'Translation/ribosome',
#  'K01963': 'Translation/ribosome',
#  'K01971': 'DNA replication/repair/maintenance',
#  'K01972': 'DNA replication/repair/maintenance',
#  'K01975': 'Nucleotide metabolism',
#  'K01989': 'Tryptophan metabolism',
#  'K01990': 'Transport',
#  'K01991': 'Transport',
#  'K01992': 'Transport',
#  'K01993': 'Transport',
#  'K01995': 'Transport',
#  'K01996': 'Transport',
#  'K01997': 'Transport',
#  'K01998': 'Transport',
#  'K01999': 'Transport',
#  'K02000': 'Transport',
#  'K02001': 'Transport',
#  'K02002': 'Transport',
#  'K02003': 'Transport',
#  'K02004': 'Transport',
#  'K02005': 'Transport',
#  'K02006': 'Transport',
#  'K02007': 'Transport',
#  'K02008': 'Transport',
#  'K02009': 'Transport',
#  'K02010': 'Transport',
#  'K02011': 'Transport',
#  'K02012': 'Transport',
#  'K02013': 'Transport',
#  'K02014': 'Transport',
#  'K02015': 'Transport',
#  'K02016': 'Transport',
#  'K02017': 'Transport',
#  'K02018': 'Transport',
#  'K02019': 'Transport',
#  'K02020': 'Transport',
#  'K02021': 'Transport',
#  'K02022': 'Transport',
#  'K02024': 'Other',
#  'K02025': 'Transport',
#  'K02026': 'Transport',
#  'K02027': 'Transport',
#  'K02028': 'Transport',
#  'K02029': 'Transport',
#  'K02030': 'Transport',
#  'K02031': 'Transport',
#  'K02032': 'Transport',
#  'K02033': 'Transport',
#  'K02034': 'Transport',
#  'K02035': 'Transport',
#  'K02036': 'Transport',
#  'K02037': 'Transport',
#  'K02038': 'Transport',
#  'K02039': 'Transport',
#  'K02040': 'Transport',
#  'K02041': 'Transport',
#  'K02042': 'Transport',
#  'K02043': 'Transcriptional regulation',
#  'K02044': 'Transport',
#  'K02045': 'Transport',
#  'K02046': 'Transport',
#  'K02047': 'Transport',
#  'K02048': 'Transport',
#  'K02049': 'Transport',
#  'K02050': 'Transport',
#  'K02051': 'Transport',
#  'K02052': 'Transport',
#  'K02053': 'Transport',
#  'K02054': 'Transport',
#  'K02055': 'Transport',
#  'K02056': 'Transport',
#  'K02057': 'Transport',
#  'K02058': 'Transport',
#  'K02062': 'Transport',
#  'K02063': 'Transport',
#  'K02064': 'Transport',
#  'K02065': 'Transport',
#  'K02066': 'Transport',
#  'K02067': 'Transport',
#  'K02068': 'Transport',
#  'K02069': 'Transport',
#  'K02071': 'Transport',
#  'K02072': 'Transport',
#  'K02073': 'Transport',
#  'K02074': 'Transport',
#  'K02075': 'Transport',
#  'K02076': 'Transcriptional regulation',
#  'K02077': 'Transport',
#  'K02078': 'Lipid metabolism',
#  'K02081': 'Transcriptional regulation',
#  'K02082': 'Energy/central carbon',
#  'K02083': 'Carbohydrate metabolism',
#  'K02086': 'DNA replication/repair/maintenance',
#  'K02099': 'Transcriptional regulation',
#  'K02100': 'Antibiotic resistance/efflux',
#  'K02103': 'Transcriptional regulation',
#  'K02108': 'Transport',
#  'K02109': 'Transport',
#  'K02110': 'Transport',
#  'K02111': 'Transport',
#  'K02112': 'Transport',
#  'K02113': 'Transport',
#  'K02114': 'Transport',
#  'K02115': 'Transport',
#  'K02116': 'Other',
#  'K02160': 'Cofactors/vitamins',
#  'K02167': 'Transcriptional regulation',
#  'K02168': 'Transport',
#  'K02169': 'Carbohydrate metabolism',
#  'K02170': 'Carbohydrate metabolism',
#  'K02171': 'Antibiotic resistance/efflux',
#  'K02182': 'Translation/ribosome',
#  'K02188': 'Carbohydrate metabolism',
#  'K02189': 'Carbohydrate metabolism',
#  'K02190': 'Energy/central carbon',
#  'K02191': 'Carbohydrate metabolism',
#  'K02192': 'Defense systems',
#  'K02193': 'Transport',
#  'K02194': 'Transport',
#  'K02195': 'Transport',
#  'K02197': 'Translation/ribosome',
#  'K02198': 'Translation/ribosome',
#  'K02199': 'Translation/ribosome',
#  'K02200': 'Translation/ribosome',
#  'K02204': 'Carbohydrate metabolism',
#  ...}

# %%
embed_cfg
# Out:
# {'min_prev_x_abs': 3, 'pseudocount_x': 0.5, 'n_components': 16}

# %%
from intelligrate.extrapolate.embedding import fit_x_embedding_svd_clr
from intelligrate.extrapolate.fixed_param_sweep import run_fixed_param_sweep_explicit

# Fit embedding on all samples (X_full)
embed = fit_x_embedding_svd_clr(
    X_full,
    min_prev_x_abs=int(embed_cfg['min_prev_x_abs']),
    pseudocount_x=float(embed_cfg['pseudocount_x']),
    n_components=int(embed_cfg['n_components']),
    seed=int(cv_cfg['seed']),
)

embed_path = results_dir / 'embed.joblib'
joblib.dump(embed, embed_path)
print('Saved embedding to:', embed_path)

# Define a small fixed-parameter sweep (uses the same X_full/X/Y/ko_to_superclass as above)
cfg["fixed_param_sweep"] = {
    "neigh_k": [18, 20, 22],
    "tau_mult": [0.5, 1.0],
    "y_latent_k": [5, 10, 15],
    "metric_ridge": [1.0, 2.5],
}

sweep_out = results_dir / "fixed_param_sweep.tsv"
sweep_df = run_fixed_param_sweep_explicit(
    X_full=X_full,
    X=X,
    Y=Y,
    ko_to_superclass=None,
    out_path=sweep_out,
    cv_cfg=cv_cfg,
    embed_cfg=embed_cfg,
    model_cfg=model_cfg,
    prf_cfg=prf_cfg,
    metrics_cfg=metrics_cfg,
    sweep_cfg=cfg["fixed_param_sweep"],
    embed=embed,
    
)
sweep_df.head()
# Out:
# Saved embedding to: /Users/meyeanni/Desktop/git_sourdough/Intelligrate/results/primates_ecs/embed.joblib
#     neigh_k  tau_mult  y_latent_k  metric_ridge  lam  min_prev_y_abs  \
# 4        18       0.5          15           1.0  0.0               1
# 5        18       0.5          15           2.5  0.0               1
# 17       20       0.5          15           2.5  0.0               1
# 16       20       0.5          15           1.0  0.0               1
# 29       22       0.5          15           2.5  0.0               1
#
#     y_detect_threshold  pseudocount_y  metric_max_pairs  tau_scale_k_nn  ...  \
# 4               1000.0   5.000000e-07              5000              10  ...
# 5               1000.0   5.000000e-07              5000              10  ...
# 17              1000.0   5.000000e-07              5000              10  ...
# 16              1000.0   5.000000e-07              5000              10  ...
# 29              1000.0   5.000000e-07              5000              10  ...
#
#     ood_lam_cap  ood_tau_inflate  ood_tau_gamma  use_metric_learning  \
# 4           0.5            False            1.0                 True
# 5           0.5            False            1.0                 True
# 17          0.5            False            1.0                 True
# 16          0.5            False            1.0                 True
# 29          0.5            False            1.0                 True
#
#     outer_splits  seed  informed_splits  dm_union_strict  dm_union_raw  \
# 4              5     0            False         0.870624      0.103938
# 5              5     0            False         0.870624      0.103938
# 17             5     0            False         0.869978      0.103737
# 16             5     0            False         0.869978      0.103737
# 29             5     0            False         0.869900      0.103472
#
#     runtime_s
# 4    0.597704
# 5    0.601531
# 17   0.567679
# 16   0.571233
# 29   0.568207
#
# [5 rows x 22 columns]

# %%
#check which sweep params give the best dm_union_strict:
sweep_df.sort_values('dm_union_raw', ascending=False).head()
# Out:
#     neigh_k  tau_mult  y_latent_k  metric_ridge  lam  min_prev_y_abs  \
# 4        18       0.5          15           1.0  0.0               1
# 5        18       0.5          15           2.5  0.0               1
# 17       20       0.5          15           2.5  0.0               1
# 16       20       0.5          15           1.0  0.0               1
# 29       22       0.5          15           2.5  0.0               1
#
#     y_detect_threshold  pseudocount_y  metric_max_pairs  tau_scale_k_nn  ...  \
# 4               1000.0   5.000000e-07              5000              10  ...
# 5               1000.0   5.000000e-07              5000              10  ...
# 17              1000.0   5.000000e-07              5000              10  ...
# 16              1000.0   5.000000e-07              5000              10  ...
# 29              1000.0   5.000000e-07              5000              10  ...
#
#     ood_lam_cap  ood_tau_inflate  ood_tau_gamma  use_metric_learning  \
# 4           0.5            False            1.0                 True
# 5           0.5            False            1.0                 True
# 17          0.5            False            1.0                 True
# 16          0.5            False            1.0                 True
# 29          0.5            False            1.0                 True
#
#     outer_splits  seed  informed_splits  dm_union_strict  dm_union_raw  \
# 4              5     0            False         0.870624      0.103938
# 5              5     0            False         0.870624      0.103938
# 17             5     0            False         0.869978      0.103737
# 16             5     0            False         0.869978      0.103737
# 29             5     0            False         0.869900      0.103472
#
#     runtime_s
# 4    0.597704
# 5    0.601531
# 17   0.567679
# 16   0.571233
# 29   0.568207
#
# [5 rows x 22 columns]

# %% [markdown]
# -> in this case the best config is neight_k = 28, tau_mult = 0.5, y_latent_k = 20, metric_ridge = 2.5

# %% [markdown]
# ### now if you want to try a few more fixed parameter combos, go ahead, otherwise skip and continue with the full fit of the final model further down

# %%
# Define a small fixed-parameter sweep (uses the same X_full/X/Y/ko_to_superclass as above), round 2:
cfg["fixed_param_sweep"] = {
    "neigh_k": [5, 10, 12, 18],
    "tau_mult": [0.35, 0.5, 0.65],
    "y_latent_k": [13, 15, 17],
    "metric_ridge": [1],
}

sweep_out2 = results_dir / "fixed_param_sweep2.tsv"
sweep_df2 = run_fixed_param_sweep_explicit(
    X_full=X_full,
    X=X,
    Y=Y,
    ko_to_superclass=None,
    out_path=sweep_out,
    cv_cfg=cv_cfg,
    embed_cfg=embed_cfg,
    model_cfg=model_cfg,
    prf_cfg=prf_cfg,
    metrics_cfg=metrics_cfg,
    sweep_cfg=cfg["fixed_param_sweep"],
    embed=embed,
)
sweep_df2.head()
# Out:
#     neigh_k  tau_mult  y_latent_k  metric_ridge  lam  min_prev_y_abs  \
# 1         5      0.35          15           1.0  0.0               1
# 2         5      0.35          17           1.0  0.0               1
# 29       18      0.35          17           1.0  0.0               1
# 28       18      0.35          15           1.0  0.0               1
# 11       10      0.35          17           1.0  0.0               1
#
#     y_detect_threshold  pseudocount_y  metric_max_pairs  tau_scale_k_nn  ...  \
# 1               1000.0   5.000000e-07              5000              10  ...
# 2               1000.0   5.000000e-07              5000              10  ...
# 29              1000.0   5.000000e-07              5000              10  ...
# 28              1000.0   5.000000e-07              5000              10  ...
# 11              1000.0   5.000000e-07              5000              10  ...
#
#     ood_lam_cap  ood_tau_inflate  ood_tau_gamma  use_metric_learning  \
# 1           0.5            False            1.0                 True
# 2           0.5            False            1.0                 True
# 29          0.5            False            1.0                 True
# 28          0.5            False            1.0                 True
# 11          0.5            False            1.0                 True
#
#     outer_splits  seed  informed_splits  dm_union_strict  dm_union_raw  \
# 1              5     0            False         0.880261      0.107078
# 2              5     0            False         0.879119      0.106700
# 29             5     0            False         0.879021      0.106334
# 28             5     0            False         0.878427      0.106709
# 11             5     0            False         0.878365      0.106774
#
#     runtime_s
# 1    0.628664
# 2    0.609227
# 29   0.559960
# 28   0.570536
# 11   0.674621
#
# [5 rows x 22 columns]

# %%
sweep_df2.sort_values('dm_union_raw', ascending=False).head()
# Out:
#     neigh_k  tau_mult  y_latent_k  metric_ridge  lam  min_prev_y_abs  \
# 10       10      0.35          15           1.0  0.0               1
# 9        10      0.35          13           1.0  0.0               1
# 1         5      0.35          15           1.0  0.0               1
# 0         5      0.35          13           1.0  0.0               1
# 19       12      0.35          15           1.0  0.0               1
#
#     y_detect_threshold  pseudocount_y  metric_max_pairs  tau_scale_k_nn  ...  \
# 10              1000.0   5.000000e-07              5000              10  ...
# 9               1000.0   5.000000e-07              5000              10  ...
# 1               1000.0   5.000000e-07              5000              10  ...
# 0               1000.0   5.000000e-07              5000              10  ...
# 19              1000.0   5.000000e-07              5000              10  ...
#
#     ood_lam_cap  ood_tau_inflate  ood_tau_gamma  use_metric_learning  \
# 10          0.5            False            1.0                 True
# 9           0.5            False            1.0                 True
# 1           0.5            False            1.0                 True
# 0           0.5            False            1.0                 True
# 19          0.5            False            1.0                 True
#
#     outer_splits  seed  informed_splits  dm_union_strict  dm_union_raw  \
# 10             5     0            False         0.878335      0.107173
# 9              5     0            False         0.877399      0.107098
# 1              5     0            False         0.880261      0.107078
# 0              5     0            False         0.877507      0.106975
# 19             5     0            False         0.878356      0.106953
#
#     runtime_s
# 10   0.595005
# 9    0.594906
# 1    0.628664
# 0    0.660702
# 19   0.563300
#
# [5 rows x 22 columns]

# %%
# Define a small fixed-parameter sweep (uses the same X_full/X/Y/ko_to_superclass as above), round 3: keep best ones, sweep y_latent_k
cfg["fixed_param_sweep"] = {
    "neigh_k": [3, 4, 5, 6],
    "tau_mult": [0.1, 0.25, 0.35, 0.5],
    "y_latent_k": [15],
    "metric_ridge": [1, 2.5, 5],
    
}

sweep_out3 = results_dir / "fixed_param_sweep3.tsv"
sweep_df3 = run_fixed_param_sweep_explicit(
    X_full=X_full,
    X=X,
    Y=Y,
    ko_to_superclass=None,
    out_path=sweep_out,
    cv_cfg=cv_cfg,
    embed_cfg=embed_cfg,
    model_cfg=model_cfg,
    prf_cfg=prf_cfg,
    metrics_cfg=metrics_cfg,
    sweep_cfg=cfg["fixed_param_sweep"],
    embed=embed,
)
sweep_df3.head()
# Out:
#     neigh_k  tau_mult  y_latent_k  metric_ridge  lam  min_prev_y_abs  \
# 29        5      0.25          15           5.0  0.0               1
# 28        5      0.25          15           2.5  0.0               1
# 27        5      0.25          15           1.0  0.0               1
# 41        6      0.25          15           5.0  0.0               1
# 40        6      0.25          15           2.5  0.0               1
#
#     y_detect_threshold  pseudocount_y  metric_max_pairs  tau_scale_k_nn  ...  \
# 29              1000.0   5.000000e-07              5000              10  ...
# 28              1000.0   5.000000e-07              5000              10  ...
# 27              1000.0   5.000000e-07              5000              10  ...
# 41              1000.0   5.000000e-07              5000              10  ...
# 40              1000.0   5.000000e-07              5000              10  ...
#
#     ood_lam_cap  ood_tau_inflate  ood_tau_gamma  use_metric_learning  \
# 29          0.5            False            1.0                 True
# 28          0.5            False            1.0                 True
# 27          0.5            False            1.0                 True
# 41          0.5            False            1.0                 True
# 40          0.5            False            1.0                 True
#
#     outer_splits  seed  informed_splits  dm_union_strict  dm_union_raw  \
# 29             5     0            False         0.883459      0.105794
# 28             5     0            False         0.883459      0.105794
# 27             5     0            False         0.883459      0.105794
# 41             5     0            False         0.883329      0.105893
# 40             5     0            False         0.883329      0.105893
#
#     runtime_s
# 29   0.571924
# 28   0.562789
# 27   0.565688
# 41   0.570084
# 40   0.566765
#
# [5 rows x 22 columns]

# %%
sweep_df3.sort_values('dm_union_strict', ascending=False).head()
# Out:
#     neigh_k  tau_mult  y_latent_k  metric_ridge  lam  min_prev_y_abs  \
# 29        5      0.25          15           5.0  0.0               1
# 27        5      0.25          15           1.0  0.0               1
# 28        5      0.25          15           2.5  0.0               1
# 41        6      0.25          15           5.0  0.0               1
# 39        6      0.25          15           1.0  0.0               1
#
#     y_detect_threshold  pseudocount_y  metric_max_pairs  tau_scale_k_nn  ...  \
# 29              1000.0   5.000000e-07              5000              10  ...
# 27              1000.0   5.000000e-07              5000              10  ...
# 28              1000.0   5.000000e-07              5000              10  ...
# 41              1000.0   5.000000e-07              5000              10  ...
# 39              1000.0   5.000000e-07              5000              10  ...
#
#     ood_lam_cap  ood_tau_inflate  ood_tau_gamma  use_metric_learning  \
# 29          0.5            False            1.0                 True
# 27          0.5            False            1.0                 True
# 28          0.5            False            1.0                 True
# 41          0.5            False            1.0                 True
# 39          0.5            False            1.0                 True
#
#     outer_splits  seed  informed_splits  dm_union_strict  dm_union_raw  \
# 29             5     0            False         0.883459      0.105794
# 27             5     0            False         0.883459      0.105794
# 28             5     0            False         0.883459      0.105794
# 41             5     0            False         0.883329      0.105893
# 39             5     0            False         0.883329      0.105893
#
#     runtime_s
# 29   0.571924
# 27   0.565688
# 28   0.562789
# 41   0.570084
# 39   0.570246
#
# [5 rows x 22 columns]

# %%
# Define a small fixed-parameter sweep (uses the same X_full/X/Y/ko_to_superclass as above), round 4: keep best one, sweep y_detect_threshold
cfg["fixed_param_sweep"] = {
    "neigh_k": [5],
    "tau_mult": [0.25],
    "y_latent_k": [15],
    "metric_ridge": [1],
    "min_prev_y_abs": [0, 1, 3, 5, 10],
    "y_detect_threshold": [0, 100.0, 500.0, 1000.0, 1500.0, 2000.0],
    "metric_max_pairs": [3000],
}

sweep_out4 = results_dir / "fixed_param_sweep4.tsv"
sweep_df4 = run_fixed_param_sweep_explicit(
    X_full=X_full,
    X=X,
    Y=Y,
    ko_to_superclass=None,
    out_path=sweep_out,
    cv_cfg=cv_cfg,
    embed_cfg=embed_cfg,
    model_cfg=model_cfg,
    prf_cfg=prf_cfg,
    metrics_cfg=metrics_cfg,
    sweep_cfg=cfg["fixed_param_sweep"],
    embed=embed,
)
sweep_df4.head()
# Out:
#    neigh_k  tau_mult  y_latent_k  metric_ridge  lam  min_prev_y_abs  \
# 5        5      0.25          15           1.0  0.0               0
# 4        5      0.25          15           1.0  0.0               0
# 3        5      0.25          15           1.0  0.0               0
# 9        5      0.25          15           1.0  0.0               1
# 8        5      0.25          15           1.0  0.0               1
#
#    y_detect_threshold  pseudocount_y  metric_max_pairs  tau_scale_k_nn  ...  \
# 5              2000.0   5.000000e-07              3000              10  ...
# 4              1500.0   5.000000e-07              3000              10  ...
# 3              1000.0   5.000000e-07              3000              10  ...
# 9              1000.0   5.000000e-07              3000              10  ...
# 8               500.0   5.000000e-07              3000              10  ...
#
#    ood_lam_cap  ood_tau_inflate  ood_tau_gamma  use_metric_learning  \
# 5          0.5            False            1.0                 True
# 4          0.5            False            1.0                 True
# 3          0.5            False            1.0                 True
# 9          0.5            False            1.0                 True
# 8          0.5            False            1.0                 True
#
#    outer_splits  seed  informed_splits  dm_union_strict  dm_union_raw  \
# 5             5     0            False         0.931120      0.558163
# 4             5     0            False         0.929755      0.558163
# 3             5     0            False         0.929417      0.558163
# 9             5     0            False         0.883459      0.105794
# 8             5     0            False         0.874613      0.112960
#
#    runtime_s
# 5   0.934590
# 4   1.031572
# 3   0.912536
# 9   0.575686
# 8   0.603155
#
# [5 rows x 22 columns]

# %%
sweep_df4.sort_values('dm_union_strict', ascending=False).head()
# Out:
#    neigh_k  tau_mult  y_latent_k  metric_ridge  lam  min_prev_y_abs  \
# 5        5      0.25          15           1.0  0.0               0
# 4        5      0.25          15           1.0  0.0               0
# 3        5      0.25          15           1.0  0.0               0
# 9        5      0.25          15           1.0  0.0               1
# 8        5      0.25          15           1.0  0.0               1
#
#    y_detect_threshold  pseudocount_y  metric_max_pairs  tau_scale_k_nn  ...  \
# 5              2000.0   5.000000e-07              3000              10  ...
# 4              1500.0   5.000000e-07              3000              10  ...
# 3              1000.0   5.000000e-07              3000              10  ...
# 9              1000.0   5.000000e-07              3000              10  ...
# 8               500.0   5.000000e-07              3000              10  ...
#
#    ood_lam_cap  ood_tau_inflate  ood_tau_gamma  use_metric_learning  \
# 5          0.5            False            1.0                 True
# 4          0.5            False            1.0                 True
# 3          0.5            False            1.0                 True
# 9          0.5            False            1.0                 True
# 8          0.5            False            1.0                 True
#
#    outer_splits  seed  informed_splits  dm_union_strict  dm_union_raw  \
# 5             5     0            False         0.931120      0.558163
# 4             5     0            False         0.929755      0.558163
# 3             5     0            False         0.929417      0.558163
# 9             5     0            False         0.883459      0.105794
# 8             5     0            False         0.874613      0.112960
#
#    runtime_s
# 5   0.934590
# 4   1.031572
# 3   0.912536
# 9   0.575686
# 8   0.603155
#
# [5 rows x 22 columns]

# %%
cfg["fixed_param_sweep"] = {
    "neigh_k": [5],
    "tau_mult": [0.25],
    "y_latent_k": [15],
    "metric_ridge": [1],
    "min_prev_y_abs": [0],
    "y_detect_threshold": [2000, 2500, 3000],
    "metric_max_pairs": [3000],
}

sweep_out4x = results_dir / "fixed_param_sweep4.tsv"
sweep_df4x = run_fixed_param_sweep_explicit(
    X_full=X_full,
    X=X,
    Y=Y,
    ko_to_superclass=None,
    out_path=sweep_out,
    cv_cfg=cv_cfg,
    embed_cfg=embed_cfg,
    model_cfg=model_cfg,
    prf_cfg=prf_cfg,
    metrics_cfg=metrics_cfg,
    sweep_cfg=cfg["fixed_param_sweep"],
    embed=embed,
)
sweep_df4x.head()
# Out:
#    neigh_k  tau_mult  y_latent_k  metric_ridge  lam  min_prev_y_abs  \
# 0        5      0.25          15           1.0  0.0               0
# 1        5      0.25          15           1.0  0.0               0
# 2        5      0.25          15           1.0  0.0               0
#
#    y_detect_threshold  pseudocount_y  metric_max_pairs  tau_scale_k_nn  ...  \
# 0              2000.0   5.000000e-07              3000              10  ...
# 1              2500.0   5.000000e-07              3000              10  ...
# 2              3000.0   5.000000e-07              3000              10  ...
#
#    ood_lam_cap  ood_tau_inflate  ood_tau_gamma  use_metric_learning  \
# 0          0.5            False            1.0                 True
# 1          0.5            False            1.0                 True
# 2          0.5            False            1.0                 True
#
#    outer_splits  seed  informed_splits  dm_union_strict  dm_union_raw  \
# 0             5     0            False         0.931120      0.558163
# 1             5     0            False         0.902276      0.558163
# 2             5     0            False         0.857213      0.558163
#
#    runtime_s
# 0   1.011447
# 1   0.981213
# 2   0.915398
#
# [3 rows x 22 columns]

# %%
sweep_df4x.sort_values('dm_union_raw', ascending=False).head()
# Out:
#    neigh_k  tau_mult  y_latent_k  metric_ridge  lam  min_prev_y_abs  \
# 0        5      0.25          15           1.0  0.0               0
# 1        5      0.25          15           1.0  0.0               0
# 2        5      0.25          15           1.0  0.0               0
#
#    y_detect_threshold  pseudocount_y  metric_max_pairs  tau_scale_k_nn  ...  \
# 0              2000.0   5.000000e-07              3000              10  ...
# 1              2500.0   5.000000e-07              3000              10  ...
# 2              3000.0   5.000000e-07              3000              10  ...
#
#    ood_lam_cap  ood_tau_inflate  ood_tau_gamma  use_metric_learning  \
# 0          0.5            False            1.0                 True
# 1          0.5            False            1.0                 True
# 2          0.5            False            1.0                 True
#
#    outer_splits  seed  informed_splits  dm_union_strict  dm_union_raw  \
# 0             5     0            False         0.931120      0.558163
# 1             5     0            False         0.902276      0.558163
# 2             5     0            False         0.857213      0.558163
#
#    runtime_s
# 0   1.011447
# 1   0.981213
# 2   0.915398
#
# [3 rows x 22 columns]

# %%
# Define a small fixed-parameter sweep (uses the same X_full/X/Y/ko_to_superclass as above), round 4: keep best one, sweep y_detect_threshold
cfg["fixed_param_sweep"] = {
    "neigh_k": [5],
    "tau_mult": [0.25],
    "y_latent_k": [15],
    "metric_ridge": [1],
    "min_prev_y_abs": [0],
    "y_detect_threshold": [2000],
    "metric_max_pairs": [3000],
    "lam": [0.0, 0.1, 0.2, 0.5, 1],
}

sweep_out5 = results_dir / "fixed_param_sweep5.tsv"
sweep_df5 = run_fixed_param_sweep_explicit(
    X_full=X_full,
    X=X,
    Y=Y,
    ko_to_superclass=None,
    out_path=sweep_out,
    cv_cfg=cv_cfg,
    embed_cfg=embed_cfg,
    model_cfg=model_cfg,
    prf_cfg=prf_cfg,
    metrics_cfg=metrics_cfg,
    sweep_cfg=cfg["fixed_param_sweep"],
    embed=embed,
)
sweep_df5.head()
# Out:
#    neigh_k  tau_mult  y_latent_k  metric_ridge  lam  min_prev_y_abs  \
# 0        5      0.25          15           1.0  0.0               0
# 1        5      0.25          15           1.0  0.1               0
# 2        5      0.25          15           1.0  0.2               0
# 3        5      0.25          15           1.0  0.5               0
# 4        5      0.25          15           1.0  1.0               0
#
#    y_detect_threshold  pseudocount_y  metric_max_pairs  tau_scale_k_nn  ...  \
# 0              2000.0   5.000000e-07              3000              10  ...
# 1              2000.0   5.000000e-07              3000              10  ...
# 2              2000.0   5.000000e-07              3000              10  ...
# 3              2000.0   5.000000e-07              3000              10  ...
# 4              2000.0   5.000000e-07              3000              10  ...
#
#    ood_lam_cap  ood_tau_inflate  ood_tau_gamma  use_metric_learning  \
# 0          0.5            False            1.0                 True
# 1          0.5            False            1.0                 True
# 2          0.5            False            1.0                 True
# 3          0.5            False            1.0                 True
# 4          0.5            False            1.0                 True
#
#    outer_splits  seed  informed_splits  dm_union_strict  dm_union_raw  \
# 0             5     0            False         0.931120      0.558163
# 1             5     0            False         0.928905      0.558035
# 2             5     0            False         0.924951      0.557748
# 3             5     0            False         0.905051      0.553096
# 4             5     0            False         0.890019      0.048068
#
#    runtime_s
# 0   0.952496
# 1   0.925228
# 2   0.896852
# 3   0.873544
# 4   0.854478
#
# [5 rows x 22 columns]

# %%
sweep_df5.sort_values('dm_union_strict', ascending=False).head()
# Out:
#    neigh_k  tau_mult  y_latent_k  metric_ridge  lam  min_prev_y_abs  \
# 0        5      0.25          15           1.0  0.0               0
# 1        5      0.25          15           1.0  0.1               0
# 2        5      0.25          15           1.0  0.2               0
# 3        5      0.25          15           1.0  0.5               0
# 4        5      0.25          15           1.0  1.0               0
#
#    y_detect_threshold  pseudocount_y  metric_max_pairs  tau_scale_k_nn  ...  \
# 0              2000.0   5.000000e-07              3000              10  ...
# 1              2000.0   5.000000e-07              3000              10  ...
# 2              2000.0   5.000000e-07              3000              10  ...
# 3              2000.0   5.000000e-07              3000              10  ...
# 4              2000.0   5.000000e-07              3000              10  ...
#
#    ood_lam_cap  ood_tau_inflate  ood_tau_gamma  use_metric_learning  \
# 0          0.5            False            1.0                 True
# 1          0.5            False            1.0                 True
# 2          0.5            False            1.0                 True
# 3          0.5            False            1.0                 True
# 4          0.5            False            1.0                 True
#
#    outer_splits  seed  informed_splits  dm_union_strict  dm_union_raw  \
# 0             5     0            False         0.931120      0.558163
# 1             5     0            False         0.928905      0.558035
# 2             5     0            False         0.924951      0.557748
# 3             5     0            False         0.905051      0.553096
# 4             5     0            False         0.890019      0.048068
#
#    runtime_s
# 0   0.952496
# 1   0.925228
# 2   0.896852
# 3   0.873544
# 4   0.854478
#
# [5 rows x 22 columns]

# %%
# Define a small fixed-parameter sweep (uses the same X_full/X/Y/ko_to_superclass as above), round 4: keep best one, sweep y_detect_threshold
cfg["fixed_param_sweep"] = {
    "neigh_k": [5],
    "tau_mult": [0.25],
    "y_latent_k": [15],
    "metric_ridge": [1],
    "min_prev_y_abs": [0],
    "y_detect_threshold": [2000],
    "metric_max_pairs": [3000],
    "lam": [0.0],   
    
}

sweep_out6 = results_dir / "fixed_param_sweep6.tsv"
sweep_df6 = run_fixed_param_sweep_explicit(
    X_full=X_full,
    X=X,
    Y=Y,
    ko_to_superclass=None,
    out_path=sweep_out,
    cv_cfg=cv_cfg,
    embed_cfg=embed_cfg,
    model_cfg=model_cfg,
    prf_cfg=prf_cfg,
    metrics_cfg=metrics_cfg,
    sweep_cfg=cfg["fixed_param_sweep"],
    embed=embed,
)
sweep_df6.head()
# Out:
#    neigh_k  tau_mult  y_latent_k  metric_ridge  lam  min_prev_y_abs  \
# 0        5      0.25          15           1.0  0.0               0
#
#    y_detect_threshold  pseudocount_y  metric_max_pairs  tau_scale_k_nn  ...  \
# 0              2000.0   5.000000e-07              3000              10  ...
#
#    ood_lam_cap  ood_tau_inflate  ood_tau_gamma  use_metric_learning  \
# 0          0.5            False            1.0                 True
#
#    outer_splits  seed  informed_splits  dm_union_strict  dm_union_raw  \
# 0             5     0            False          0.93112      0.558163
#
#    runtime_s
# 0   0.977465
#
# [1 rows x 22 columns]

# %%
sweep_df6.sort_values('dm_union_strict', ascending=False).head()
# Out:
#    neigh_k  tau_mult  y_latent_k  metric_ridge  lam  min_prev_y_abs  \
# 0        5      0.25          15           1.0  0.0               0
#
#    y_detect_threshold  pseudocount_y  metric_max_pairs  tau_scale_k_nn  ...  \
# 0              2000.0   5.000000e-07              3000              10  ...
#
#    ood_lam_cap  ood_tau_inflate  ood_tau_gamma  use_metric_learning  \
# 0          0.5            False            1.0                 True
#
#    outer_splits  seed  informed_splits  dm_union_strict  dm_union_raw  \
# 0             5     0            False          0.93112      0.558163
#
#    runtime_s
# 0   0.977465
#
# [1 rows x 22 columns]

# %% [markdown]
# -> that's the final choice for now (sweep_df6)!

# %% [markdown]
# ## 2) Full fit (final model)
# We fit the embedding on all k-mer samples (same as before, but now parameters are exposed in case we would still want to update/improve some based on previous grid scans), then fit a final model on paired samples.
#
# To pick hyperparameters, we take the most common (mode) values from the CV folds.
# You can also set them manually.

# %% [markdown]
# ### option 1 to get the best params from fits without sweep:

# %%
from intelligrate.extrapolate.full_fit import fit_final_model, save_model



# Choose final hyperparameters from folds (mode) -> the ones that were most often selected
def mode_or_first(series, default):
    if series is None or series.empty:
        return default
    return series.mode().iloc[0]

neigh_k = int(mode_or_first(folds.get('neigh_k'), model_cfg['neigh_k_grid'][0]))
tau_mult = float(mode_or_first(folds.get('tau_mult'), model_cfg['tau_mult_grid'][0]))
lam = float(mode_or_first(folds.get('lam'), model_cfg['lam_grid'][0]))
y_latent_k = int(mode_or_first(folds.get('y_latent_k'), model_cfg['y_latent_k_grid'][0]))
metric_ridge = float(mode_or_first(folds.get('metric_ridge'), model_cfg['metric_ridge_grid'][0]))

print('Selected hyperparameters:', neigh_k, tau_mult, lam, y_latent_k, metric_ridge)
# Out:
# Selected hyperparameters: 20 0.5 0.0 10 1.0

# %% [markdown]
# ### option 2 to get the best params from fixed param sweep (which we will do now!)

# %%
from intelligrate.extrapolate.full_fit import fit_final_model, save_model

#which sweep_df should be considered? adapt here
sweep_final = sweep_df6.copy()

# Choose final hyperparameters from folds (mode) -> the ones that were most often selected
def mode_or_first(series, default):
    if series is None or series.empty:
        return default
    return series.mode().iloc[0]

neigh_k = int(mode_or_first(sweep_final.get('neigh_k'), model_cfg['neigh_k_grid'][0]))
tau_mult = float(mode_or_first(sweep_final.get('tau_mult'), model_cfg['tau_mult_grid'][0]))
lam = float(mode_or_first(sweep_final.get('lam'), model_cfg['lam_grid'][0]))
y_latent_k = int(mode_or_first(sweep_final.get('y_latent_k'), model_cfg['y_latent_k_grid'][0]))
metric_ridge = float(mode_or_first(sweep_final.get('metric_ridge'), model_cfg['metric_ridge_grid'][0]))
min_prev_y_abs = int(mode_or_first(sweep_final.get('min_prev_y_abs'), model_cfg['min_prev_y_abs']))
y_detect_threshold = float(mode_or_first(sweep_final.get('y_detect_threshold'), model_cfg['y_detect_threshold']))
metric_max_pairs = int(mode_or_first(sweep_final.get('metric_max_pairs'), model_cfg['metric_max_pairs']))

print('Selected hyperparameters:', neigh_k, tau_mult, lam, y_latent_k, metric_ridge, min_prev_y_abs, y_detect_threshold, metric_max_pairs)
# Out:
# Selected hyperparameters: 5 0.25 0.0 15 1.0 0 2000.0 3000

# %% [markdown]
# then, we fit the final model which we will then apply for extrapolation.

# %%
model = fit_final_model(
    X_train=X,
    Y_train_tpm=Y,
    embed=embed,
    min_prev_y_abs=min_prev_y_abs,
    y_detect_threshold=y_detect_threshold,
    pseudocount_y=float(model_cfg['pseudocount_y']),
    neigh_k=neigh_k,
    tau_mult=tau_mult,
    lam=lam,
    y_latent_k=y_latent_k,
    use_metric_learning=bool(model_cfg['use_metric_learning']),
    metric_ridge=metric_ridge,
    metric_max_pairs=metric_max_pairs,
    tau_scale_k_nn=int(model_cfg.get('tau_scale_k_nn', 10)),
    ood_shrink=bool(model_cfg.get('ood_shrink', False)),
    ood_lam_base=float(model_cfg.get('ood_lam_base', 0.1)),
    ood_lam_cap=float(model_cfg.get('ood_lam_cap', 0.8)),
    seed=int(cv_cfg['seed']),
)

model_path = save_model(model, results_dir / 'model.joblib')
print('Saved model to:', model_path)
# Out:
# Saved model to: /Users/meyeanni/Desktop/git_sourdough/Intelligrate/results/primates_ecs/model.joblib

# %% [markdown]
# ## 3) Full predict (= extrapolate)
# We predict for all samples, then (optionally) evaluate on the paired subset if truth is available.

# %%
from intelligrate.extrapolate.full_predict import predict_final_model, evaluate_paired_subset

# Predict for all samples (deployment)
Yhat_clr, Yhat_tss, diag = predict_final_model(X_full, model)

# We will save only the leakage-free version after replacing paired rows.

# %% [markdown]
# ## Leakage-free paired predictions (fixed-parameter OOF)
# We re-predict paired samples using fixed hyperparameters, training only on other samples.
# Set outer_splits = N to emulate leave-one-out.

# %%
from intelligrate.extrapolate.cv_knn import fixed_param_oof_knn_on_embedding

oof_fixed_clr, oof_fixed_tss, oof_fixed_folds = fixed_param_oof_knn_on_embedding(
    X=X,
    Y_tpm=Y,
    embed=embed,
    ko_to_superclass=None,
    outer_splits=5,  # set to len(X) for leave-one-out
    seed=int(cv_cfg['seed']),
    min_prev_y_abs=min_prev_y_abs,
    y_detect_threshold=y_detect_threshold,
    pseudocount_y=float(model_cfg['pseudocount_y']),
    neigh_k=int(neigh_k),
    tau_mult=float(tau_mult),
    lam=float(lam),
    y_latent_k=int(y_latent_k),
    use_metric_learning=bool(model_cfg['use_metric_learning']),
    metric_max_pairs=metric_max_pairs,
    metric_ridge=float(metric_ridge),
    tau_scale_k_nn=int(model_cfg.get('tau_scale_k_nn', 10)),
    ood_shrink=bool(model_cfg.get('ood_shrink', False)),
    ood_lam_base=float(model_cfg.get('ood_lam_base', 0.1)),
    ood_lam_cap=float(model_cfg.get('ood_lam_cap', 0.8)),
    ood_tau_inflate=bool(model_cfg.get('ood_tau_inflate', False)),
    ood_tau_gamma=float(model_cfg.get('ood_tau_gamma', 1.0)),
    informed_splits=bool(cv_cfg.get('informed_splits', False)),
    informed_kmeans_on='X',
    prf_thresh=float(prf_cfg['prf_thresh']),
    prf_weight=str(prf_cfg['prf_weight']),
)

#drop columns if they are all nan or all 0:
oof_fixed_clr = oof_fixed_clr.loc[:, (oof_fixed_clr.notna().any()) & (oof_fixed_clr.sum(axis=0) != 0)]
oof_fixed_tss = oof_fixed_tss.loc[:, (oof_fixed_tss.notna().any()) & (oof_fixed_tss.sum(axis=0) != 0)]


oof_fixed_clr.to_csv(results_dir / 'oof_fixed_clr.tsv', sep='	')
oof_fixed_tss.to_csv(results_dir / 'oof_fixed_tss.tsv', sep='	')
oof_fixed_folds.to_csv(results_dir / 'oof_fixed_folds.tsv', sep='	', index=False)

# Replace paired rows in full predictions with leakage-free OOF predictions
# pred_full.* uses full-fit predictions for unpaired samples, but paired rows are OOF (leakage-free).
Yhat_clr_full_oof = Yhat_clr.copy()
Yhat_tss_full_oof = Yhat_tss.copy()
# Yhat_clr_full_oof.loc[X.index] = oof_fixed_clr.loc[X.index]
# Yhat_tss_full_oof.loc[X.index] = oof_fixed_tss.loc[X.index]
 # Align columns to full prediction columns
oof_fixed_clr_aligned = oof_fixed_clr.reindex(columns=Yhat_clr_full_oof.columns)
oof_fixed_tss_aligned = oof_fixed_tss.reindex(columns=Yhat_tss_full_oof.columns)

if oof_fixed_clr_aligned.isna().any().sum() > 0:
  oof_fixed_clr_aligned = oof_fixed_clr_aligned.fillna(0.0)
if oof_fixed_tss_aligned.isna().any().sum() > 0:
    oof_fixed_tss_aligned = oof_fixed_tss_aligned.fillna(0.0)

Yhat_clr_full_oof.loc[X.index] = oof_fixed_clr_aligned.loc[X.index]
Yhat_tss_full_oof.loc[X.index] = oof_fixed_tss_aligned.loc[X.index]

pred_full_prefix = results_dir / 'pred_full'
Yhat_clr_full_oof.to_csv(pred_full_prefix.with_suffix('.clr.tsv'), sep='	')
Yhat_tss_full_oof.to_csv(pred_full_prefix.with_suffix('.tss.tsv'), sep='	')

# Evaluate leakage-free paired predictions
metrics_oof = evaluate_paired_subset(
    truth_tpm=Y,
    pred_tss=oof_fixed_tss,
    pseudocount=float(model_cfg['pseudocount_y']),
    detect_threshold=y_detect_threshold,
    prf_thresh=float(prf_cfg['prf_thresh']),
    prf_weight=str(prf_cfg['prf_weight']),
    compute_wclr=bool(metrics_cfg['compute_wclr']),
    compute_jsd=bool(metrics_cfg['compute_jsd']),
    compute_pathway=bool(metrics_cfg['compute_pathway_rmse']),
    compute_per_pathway=bool(metrics_cfg['pathway_rmse_per_group']),
    ko_to_group=None,
    log1p_pathway=bool(metrics_cfg['pathway_rmse_log1p']),
    compute_null=True,
    null_n=50, #decrease for speed, increase for stability
    null_seed=0,
    null_mean_noise_scale=0.0001,
)

pd.DataFrame([metrics_oof]).to_csv(results_dir / 'pred_paired_oof.metrics.tsv', sep='	', index=False)
metrics_oof
# Out:
# {'dm_union_raw': 0.5581634896011032,
#  'dm_union_strict': 0.9311199139570204,
#  'bray_union_raw': 0.4876324883467098,
#  'bray_union_strict': 0.8727963177383278,
#  'procrustes_aitchison_raw': 0.6185972665218447,
#  'procrustes_aitchison_strict': 0.7868432215084951,
#  'procrustes_bray_raw': 0.5679158050185894,
#  'procrustes_bray_strict': 0.7556779640618889,
#  'dm_spearman': 0.9311199139570204,
#  'bray_spearman': 0.8727963177383278,
#  'procrustes_aitchison': 0.7868432215084951,
#  'procrustes_bray': 0.7556779640618889,
#  'soft_precision': 0.8785395136375134,
#  'soft_recall': 0.8652989453366536,
#  'soft_f1': 0.8644746290311065,
#  'wclr_mse': 5.823663742669912,
#  'jsd': 0.060684986985504875,
#  'dm_spearman_union_raw': 0.5581634896011032,
#  'bray_spearman_union_raw': 0.4876324883467098,
#  'procrustes_aitchison_union_raw': 0.6185972665218447,
#  'procrustes_bray_union_raw': 0.5679158050185894,
#  'soft_precision_union_raw': 0.8454720351676891,
#  'soft_recall_union_raw': 0.9646335735143361,
#  'soft_f1_union_raw': 0.8997074448389414,
#  'wclr_mse_union_raw': 1.6970140419792243,
#  'jsd_union_raw': 0.008878169651190626,
#  'intersection_dm_spearman': 0.5581634896011032,
#  'intersection_bray_spearman': 0.4876324883467098,
#  'intersection_procrustes_aitchison': 0.6185972665218447,
#  'intersection_procrustes_bray': 0.5679158050185892,
#  'intersection_soft_precision': 0.8454720351676891,
#  'intersection_soft_recall': 0.9646335735143361,
#  'intersection_soft_f1': 0.8997074448389414,
#  'intersection_wclr_mse': 1.6970140419792235,
#  'intersection_jsd': 0.00887816965119063,
#  'sample_spearman_tss_union_strict': 0.8684818151893052,
#  'sample_spearman_clr_union_strict': 0.8684818151893052,
#  'sample_spearman_tss_union_raw': 0.9225056290319832,
#  'sample_spearman_clr_union_raw': 0.9225056363036399,
#  'sample_spearman_tss_intersection': 0.9225056290319832,
#  'sample_spearman_clr_intersection': 0.9225056560008249,
#  'null_sample_dm_spearman_union_strict_mean': 0.019833106170617187,
#  'null_sample_dm_spearman_union_strict_std': 0.08488887082829515,
#  'null_feature_dm_spearman_union_strict_mean': 0.9287920102003139,
#  'null_feature_dm_spearman_union_strict_std': 1.1102230246251565e-16,
#  'null_mean_dm_spearman_union_strict_mean': 0.6735356301596137,
#  'null_mean_dm_spearman_union_strict_std': 0.01727024267897312,
#  'null_sample_bray_spearman_union_strict_mean': 0.0006162258262964975,
#  'null_sample_bray_spearman_union_strict_std': 0.05738266161570453,
#  'null_feature_bray_spearman_union_strict_mean': 0.8589312775466428,
#  'null_feature_bray_spearman_union_strict_std': 2.0181287487082658e-05,
#  'null_mean_bray_spearman_union_strict_mean': 0.7079230411626506,
#  'null_mean_bray_spearman_union_strict_std': 0.014420729171691791,
#  'null_sample_procrustes_aitchison_union_strict_mean': 0.05519855746664771,
#  'null_sample_procrustes_aitchison_union_strict_std': 0.019000645223684366,
#  'null_feature_procrustes_aitchison_union_strict_mean': 0.7690554209510241,
#  'null_feature_procrustes_aitchison_union_strict_std': 3.1898776780966894e-15,
#  'null_mean_procrustes_aitchison_union_strict_mean': 0.5331107458049573,
#  'null_mean_procrustes_aitchison_union_strict_std': 0.013571870067584261,
#  'null_sample_procrustes_bray_union_strict_mean': 0.043409362791737884,
#  'null_sample_procrustes_bray_union_strict_std': 0.012381554986071016,
#  'null_feature_procrustes_bray_union_strict_mean': 0.6915957569598942,
#  'null_feature_procrustes_bray_union_strict_std': 1.1212702919885052e-16,
#  'null_mean_procrustes_bray_union_strict_mean': 0.5358692375291535,
#  'null_mean_procrustes_bray_union_strict_std': 0.012690778769673925,
#  'null_sample_soft_precision_union_strict_mean': 0.7091911941837747,
#  'null_sample_soft_precision_union_strict_std': 0.010758329959571338,
#  'null_feature_soft_precision_union_strict_mean': 0.009472467040921312,
#  'null_feature_soft_precision_union_strict_std': 0.007550513096994593,
#  'null_mean_soft_precision_union_strict_mean': 0.6100805998629463,
#  'null_mean_soft_precision_union_strict_std': 0.0027405256306572683,
#  'null_sample_soft_recall_union_strict_mean': 0.6842641278839691,
#  'null_sample_soft_recall_union_strict_std': 0.013292902148265192,
#  'null_feature_soft_recall_union_strict_mean': 0.009721501349382943,
#  'null_feature_soft_recall_union_strict_std': 0.00788620158666988,
#  'null_mean_soft_recall_union_strict_mean': 0.849324871633978,
#  'null_mean_soft_recall_union_strict_std': 0.0019809984227520303,
#  'null_sample_soft_f1_union_strict_mean': 0.560564194983489,
#  'null_sample_soft_f1_union_strict_std': 0.01810320751760936,
#  'null_feature_soft_f1_union_strict_mean': 0.009513570690959584,
#  'null_feature_soft_f1_union_strict_std': 0.007642564753391893,
#  'null_mean_soft_f1_union_strict_mean': 0.6631702546663619,
#  'null_mean_soft_f1_union_strict_std': 0.0023914751568278048,
#  'null_sample_wclr_mse_union_strict_mean': 23.82124208282562,
#  'null_sample_wclr_mse_union_strict_std': 1.1256361640968047,
#  'null_feature_wclr_mse_union_strict_mean': 21.474062998559734,
#  'null_feature_wclr_mse_union_strict_std': 0.6429034603581905,
#  'null_mean_wclr_mse_union_strict_mean': 15.676548533661022,
#  'null_mean_wclr_mse_union_strict_std': 0.12772004363250453,
#  'null_sample_jsd_union_strict_mean': 0.18733556022180464,
#  'null_sample_jsd_union_strict_std': 0.007537893121988021,
#  'null_feature_jsd_union_strict_mean': 0.6873517241201477,
#  'null_feature_jsd_union_strict_std': 0.004614780916138317,
#  'null_mean_jsd_union_strict_mean': 0.1156773141823413,
#  'null_mean_jsd_union_strict_std': 0.0005570095202860263,
#  'null_sample_pathway_rmse_union_strict_mean': nan,
#  'null_sample_pathway_rmse_union_strict_std': nan,
#  'null_feature_pathway_rmse_union_strict_mean': nan,
#  'null_feature_pathway_rmse_union_strict_std': nan,
#  'null_mean_pathway_rmse_union_strict_mean': nan,
#  'null_mean_pathway_rmse_union_strict_std': nan,
#  'null_sample_sample_spearman_tss_union_strict_mean': 0.6106324192916734,
#  'null_sample_sample_spearman_tss_union_strict_std': 0.015384045992912501,
#  'null_sample_sample_spearman_clr_union_strict_mean': 0.6106324192916734,
#  'null_sample_sample_spearman_clr_union_strict_std': 0.015384045992912501,
#  'null_feature_sample_spearman_tss_union_strict_mean': -0.0006411849900350568,
#  'null_feature_sample_spearman_tss_union_strict_std': 0.007842099941996401,
#  'null_feature_sample_spearman_clr_union_strict_mean': -0.0006411849900350568,
#  'null_feature_sample_spearman_clr_union_strict_std': 0.007842099941996401,
#  'null_mean_sample_spearman_tss_union_strict_mean': 0.15315808862792615,
#  'null_mean_sample_spearman_tss_union_strict_std': 0.000397826782791099,
#  'null_mean_sample_spearman_clr_union_strict_mean': 0.15315808862792615,
#  'null_mean_sample_spearman_clr_union_strict_std': 0.000397826782791099}

# %% [markdown]
# ### KO predictability score (per-KO confidence)
# This combines conditional neighbor dispersion (lower is better) with per‑KO OOF Spearman (higher is better).

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from intelligrate.extrapolate.transforms import tss_rows, clr_rows
from intelligrate.extrapolate.embedding import transform_x_embedding_svd_clr
from intelligrate.extrapolate.metrics import ko_confidence_from_oof

# Build CLR truth and predictions
Y_clr = clr_rows(tss_rows(Y), pseudocount=float(model_cfg["pseudocount_y"]))
oof_pred_clr = oof_fixed_clr.reindex(columns=Y_clr.columns)
assert oof_pred_clr.index.equals(Y_clr.index)

#define correlation threshold:
threshold_r0 = 0.30

# Compute KO confidence (stable across datasets)
Z = transform_x_embedding_svd_clr(X, embed)
S = ko_confidence_from_oof(
    Y_true_clr=Y_clr,
    Y_pred_clr=oof_pred_clr,
    Z=Z,
    r0=threshold_r0, # correlation threshold for confidence
    k_nn=5, # neighbors for stability
    R=50, # null replicates for stability, meaning how many random sets are generated to compare to the observed ones for the stability score
    seed=0,
    min_n=5, # min samples for spearman-> min samples with non-nan values for a KO
)

# Top KOs by confidence
S.sort_values("confidence", ascending=False).head(10)

#save to tsv:
S.to_csv(results_dir / 'per_ko_confidence.tsv', sep='	')

# %%
#is there a row with nan in oof_spearman of S?
S['oof_spearman'].isna().sum()

#drop rows with nan in oof_spearman:
S = S.dropna(subset=['oof_spearman'])
S
# Out:
#               oof_spearman  n_eff  conf_corr  conf_stab  confidence
# EC:1.1.1.1        0.746385     77   1.000000   1.000000    1.000000
# EC:1.1.1.10       0.599979     77   0.999516   0.154483    0.154409
# EC:1.1.1.100      0.698670     77   0.999999   1.000000    0.999999
# EC:1.1.1.103      0.746569     77   1.000000   1.000000    1.000000
# EC:1.1.1.105      0.337399     77   0.639889   1.000000    0.639889
# ...                    ...    ...        ...        ...         ...
# EC:6.5.1.2        0.583206     77   0.998957   0.958177    0.957178
# EC:6.5.1.3        0.452916     77   0.938032   1.000000    0.938032
# EC:6.5.1.4        0.640333     77   0.999944   1.000000    0.999944
# EC:6.6.1.1        0.546322     77   0.995495   1.000000    0.995495
# EC:6.6.1.2        0.220280     77   0.230836   0.960990    0.221831
#
# [2468 rows x 5 columns]

# %%
#plot the distribution of oof_corr and cond_disp:
plt.figure(figsize=(16,4))
plt.subplot(1,4,1)
plt.hist(S["oof_spearman"].dropna(), bins=50, color='#468892FF', edgecolor=None, alpha=0.7)
plt.xlabel("Correlation", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title("OOF correlation per EC", fontsize=16)
#add the vertical lines for correlation threshold:
plt.axvline(x=threshold_r0, color='black', linestyle='--', linewidth=1)

#also add text for those lines:
plt.text(-0.2, 15, f"Threshold = {threshold_r0}", color='black', fontsize=14)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

plt.subplot(1,4,2)
plt.hist(S["conf_corr"].dropna(), bins=50, color='#468892FF', edgecolor=None, alpha=0.7)
plt.xlabel("Confidence", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title("OOF correlation confidence", fontsize=16)

plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
plt.subplot(1,4,3)
plt.hist(S["conf_stab"].dropna(), bins=50, color='#468892FF', edgecolor=None, alpha=0.7)
plt.xlabel("Confidence", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title("OOF dispersion stability confidence", fontsize=16)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)

plt.subplot(1,4,4)
plt.hist(S["confidence"].dropna(), bins=50, color='#468892FF', edgecolor=None, alpha=0.7)
plt.xlabel("Confidence", fontsize=14)
plt.ylabel("Frequency", fontsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.title("OOF confidence per EC", fontsize=16)
#calculate how many KOs have confidence > 0.5:
num_high_confidence = (S["confidence"] > 0.5).sum()
#also calculate the percentage:
percentage_high_confidence = (num_high_confidence / len(S)) * 100
#add the vertical lines for disp_low and disp_high:
plt.axvline(x=0.5, color='black', linestyle='--', linewidth=1)
#also add text for those lines:

plt.text(0.2, 100, f"ECs with conf > 0.5:\n {num_high_confidence} ({percentage_high_confidence:.1f}%)", color='black', fontsize=14)
plt.gca().spines['top'].set_visible(False)
plt.gca().spines['right'].set_visible(False)
#save the figure as pdf:
plt.tight_layout()
figure_path = results_dir / 'ko_confidence_distribution.pdf'
plt.savefig(figure_path, format='pdf', bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Compare against PICRUSt2 + null distributions (are kNN predictions better than predicting the average KO profile of the dataset?)
# We compute the same metrics for PICRUSt2 and null distributions, and compare the results.

# %% [markdown]
# this will take a while ( a few mins), you can decrease null_n for speed!

# %%
data_cfg
# Out:
# {'x_full': 'X_ASVs_full.tsv',
#  'x': 'X_ASVs.tsv',
#  'y': 'Y_ecs.tsv',
#  'picrust2': 'picrust2_ecs.tsv'}

# %%
# Load PICRUSt2 predictions if available and compute metrics
picrust_metrics = None
picrust = None
picrust_path = repo_root / "data/primates" / data_cfg["picrust2"]
if picrust_path.exists():
    picrust = pd.read_csv(picrust_path, sep="	", index_col=0)
    picrust_metrics = evaluate_paired_subset(
        truth_tpm=Y,
        pred_tss=picrust,
        pseudocount=float(model_cfg["pseudocount_y"]),
        detect_threshold=y_detect_threshold,
        prf_thresh=float(prf_cfg["prf_thresh"]),
        prf_weight=str(prf_cfg["prf_weight"]),
        compute_wclr=bool(metrics_cfg["compute_wclr"]),
        compute_jsd=bool(metrics_cfg["compute_jsd"]),
        compute_pathway=bool(metrics_cfg["compute_pathway_rmse"]),
        compute_per_pathway=bool(metrics_cfg["pathway_rmse_per_group"]),
        ko_to_group=None,
        log1p_pathway=bool(metrics_cfg["pathway_rmse_log1p"]),
        compute_null=True,
        null_n=50,
        null_seed=0,
        null_mean_noise_scale=0.0001, # null mean noise scale, meaning how much noise is added to the null predictions, the unit is in fraction of the mean of the true values
    )

# %% [markdown]
# now, we aggregate all results together for easier comparison:

# %%
len(Y.columns.intersection(oof_fixed_clr.columns))
# Out:
# 2468

# %%
len(Y.columns.union(oof_fixed_clr.columns))
# Out:
# 2468

# %%
Y
# Out:
#                  EC:1.1.1.1  EC:1.1.1.10  EC:1.1.1.100  EC:1.1.1.103  \
# 11212.RC2071        882.245          0.0       806.782       267.042
# 11212.JB34          393.862          0.0       663.437        75.725
# 11212.ERUB.20M      737.743          0.0       656.099        20.285
# 11212.JB1           413.478          0.0       478.133       102.814
# 11212.JB3           865.619          0.0      1425.914       170.603
# ...                     ...          ...           ...           ...
# 11212.LabEllis3     355.540          0.0       501.310        18.890
# 11212.BWC2026       513.341          0.0       310.141       118.507
# 11212.APF38         909.542          0.0      1140.583        54.293
# 11212.JB29          312.903          0.0       640.693       141.795
# 11212.AsenLink4     636.855          0.0       658.384        27.661
#
#                  EC:1.1.1.105  EC:1.1.1.107  EC:1.1.1.108  EC:1.1.1.11  \
# 11212.RC2071            3.218         3.359         0.000        0.000
# 11212.JB34              0.000         0.000         0.000        0.000
# 11212.ERUB.20M          0.000         0.000         0.000        5.374
# 11212.JB1               0.000         0.000         0.000        0.000
# 11212.JB3               0.000         0.000         0.000        0.000
# ...                       ...           ...           ...          ...
# 11212.LabEllis3         0.000         0.000         0.000        0.000
# 11212.BWC2026           1.111         0.000         0.000        0.000
# 11212.APF38             0.000         0.000         4.321        0.000
# 11212.JB29              0.000         0.000         0.000        0.000
# 11212.AsenLink4         0.000         0.000         0.000        0.000
#
#                  EC:1.1.1.12  EC:1.1.1.125  ...  EC:6.4.1.4  EC:6.4.1.6  \
# 11212.RC2071           1.577        32.958  ...       0.000         0.0
# 11212.JB34             0.000        19.723  ...       0.000         0.0
# 11212.ERUB.20M         2.255        20.801  ...       0.000         0.0
# 11212.JB1              0.000        26.126  ...       0.000         0.0
# 11212.JB3              0.000        47.797  ...       3.979         0.0
# ...                      ...           ...  ...         ...         ...
# 11212.LabEllis3        0.000         6.965  ...       0.000         0.0
# 11212.BWC2026          1.756        13.498  ...       0.000         0.0
# 11212.APF38            2.447        27.501  ...       0.000         0.0
# 11212.JB29             0.000        16.755  ...      23.719         0.0
# 11212.AsenLink4        0.000        33.185  ...       0.000         0.0
#
#                  EC:6.4.1.7  EC:6.4.1.8  EC:6.5.1.1  EC:6.5.1.2  EC:6.5.1.3  \
# 11212.RC2071         19.163         0.0      37.990    2599.466       0.000
# 11212.JB34           12.626         0.0      47.613    1382.822      10.438
# 11212.ERUB.20M        6.015         0.0      28.404     937.360       5.747
# 11212.JB1            37.191         0.0     206.140    1638.012      84.022
# 11212.JB3            21.317         0.0      51.575    3546.187      28.388
# ...                     ...         ...         ...         ...         ...
# 11212.LabEllis3       5.601         0.0      41.416     844.879       0.000
# 11212.BWC2026         9.218         0.0      14.980    1599.876       0.000
# 11212.APF38           9.370         0.0       0.000    1762.959       7.155
# 11212.JB29           11.754         0.0      59.259    1682.500       4.619
# 11212.AsenLink4      10.421         0.0       3.569    1598.726       0.000
#
#                  EC:6.5.1.4  EC:6.6.1.1  EC:6.6.1.2
# 11212.RC2071         20.302      34.780      31.259
# 11212.JB34           25.260      27.601      35.900
# 11212.ERUB.20M       21.316       9.543      30.463
# 11212.JB1            55.542      32.723      54.205
# 11212.JB3            32.401      69.301      70.561
# ...                     ...         ...         ...
# 11212.LabEllis3       0.000       3.227      16.243
# 11212.BWC2026         0.000      12.349       9.606
# 11212.APF38           0.000       2.892      73.502
# 11212.JB29            6.073       1.673       2.445
# 11212.AsenLink4       0.000       1.540      21.345
#
# [77 rows x 2468 columns]

# %%
oof_fixed_clr
# Out:
#                  EC:1.1.1.1  EC:1.1.1.10  EC:1.1.1.100  EC:1.1.1.103  \
# 11212.RC2071       4.803369    -3.164202      4.920989      3.020765
# 11212.JB34         4.617239    -3.147636      5.006493      3.029495
# 11212.ERUB.20M     5.076363    -3.145496      5.087013      2.163021
# 11212.JB1          4.762015    -3.105491      4.995500      2.934824
# 11212.JB3          4.620651    -3.108966      5.004115      3.081338
# ...                     ...          ...           ...           ...
# 11212.LabEllis3    4.848703    -2.993928      5.181771      2.191412
# 11212.BWC2026      4.844012    -3.042373      4.899159      3.127264
# 11212.APF38        4.981034    -2.902842      5.213691      2.505972
# 11212.JB29         4.607519    -3.133460      5.005673      2.908997
# 11212.AsenLink4    5.021701    -3.046483      5.110280      2.527744
#
#                  EC:1.1.1.105  EC:1.1.1.107  EC:1.1.1.108  EC:1.1.1.11  \
# 11212.RC2071        -1.210919     -2.427339     -2.521693    -3.074224
# 11212.JB34          -2.202654     -2.998589     -2.992757    -3.055471
# 11212.ERUB.20M      -1.677284     -3.017498     -3.163238    -1.672700
# 11212.JB1           -1.728902     -2.670763     -3.052693    -3.042943
# 11212.JB3           -2.380091     -2.829537     -2.928110    -3.105437
# ...                       ...           ...           ...          ...
# 11212.LabEllis3     -2.214126     -2.961458     -2.893326    -3.019792
# 11212.BWC2026       -2.230408     -2.780229     -2.470524    -3.046738
# 11212.APF38         -2.694089     -3.084482     -2.969960    -2.852418
# 11212.JB29          -2.503346     -2.869995     -3.038099    -3.123621
# 11212.AsenLink4     -2.222421     -2.731916     -2.792752    -2.862949
#
#                  EC:1.1.1.12  EC:1.1.1.125  ...  EC:6.4.1.4  EC:6.4.1.6  \
# 11212.RC2071       -1.990375      1.428872  ...   -1.978289   -3.023025
# 11212.JB34         -2.667556      1.220582  ...   -1.691278   -3.135133
# 11212.ERUB.20M     -1.909810      1.380629  ...   -2.701953   -3.237612
# 11212.JB1          -2.589567      1.442821  ...   -2.629730   -3.125314
# 11212.JB3          -2.757896      1.288767  ...   -1.902352   -3.117533
# ...                      ...           ...  ...         ...         ...
# 11212.LabEllis3    -2.361714      1.131529  ...   -2.769384   -3.019536
# 11212.BWC2026      -1.856787      1.450377  ...   -2.495438   -3.061106
# 11212.APF38        -1.991248      1.367744  ...   -2.689888   -3.024917
# 11212.JB29         -2.689394      1.190098  ...   -2.348820   -3.133385
# 11212.AsenLink4    -1.866516      1.506837  ...   -2.130175   -2.998970
#
#                  EC:6.4.1.7  EC:6.4.1.8  EC:6.5.1.1  EC:6.5.1.2  EC:6.5.1.3  \
# 11212.RC2071       1.420329   -3.179675    1.273959    5.789743   -0.682171
# 11212.JB34         1.190573   -3.208398    1.447733    5.859639    0.296656
# 11212.ERUB.20M     0.742488   -3.200990    1.575133    5.679637   -1.018727
# 11212.JB1          1.564947   -3.053878    1.705776    5.845926    0.071092
# 11212.JB3          1.176699   -3.105585    1.586468    5.927028    0.544478
# ...                     ...         ...         ...         ...         ...
# 11212.LabEllis3    0.861413   -2.946090    0.927613    5.900594   -0.758381
# 11212.BWC2026      1.311143   -2.998959    1.109930    5.943816   -1.546994
# 11212.APF38        0.833510   -2.978538    0.338005    5.940981   -0.745409
# 11212.JB29         1.162915   -3.142316    1.487640    5.847903    0.478305
# 11212.AsenLink4    1.042974   -2.977640    0.326578    5.925914   -0.647083
#
#                  EC:6.5.1.4  EC:6.6.1.1  EC:6.6.1.2
# 11212.RC2071      -1.094026    0.847358    1.478222
# 11212.JB34         0.037399    0.480710    1.475338
# 11212.ERUB.20M     0.717496    1.019151    2.002558
# 11212.JB1          0.558653    0.996577    1.602969
# 11212.JB3          0.129100    0.667677    1.418898
# ...                     ...         ...         ...
# 11212.LabEllis3   -1.946559    0.117203    1.764740
# 11212.BWC2026     -0.560122    0.757193    1.580255
# 11212.APF38       -1.775002   -0.324495    1.750261
# 11212.JB29         0.132504    0.841082    1.962913
# 11212.AsenLink4   -1.965047    0.281401    1.617754
#
# [77 rows x 2468 columns]

# %%
# Build a comparison table: intersection vs union_raw vs union_strict + null baselines
metrics_spec = [
    {"name": "dm_spearman", "intersection": "intersection_dm_spearman", "union_raw": "dm_union_raw", "union_strict": "dm_union_strict",
     "null_sample": "null_sample_dm_spearman_union_strict_mean", "null_feature": "null_feature_dm_spearman_union_strict_mean", "null_mean": "null_mean_dm_spearman_union_strict_mean"},
    {"name": "bray_spearman", "intersection": "intersection_bray_spearman", "union_raw": "bray_union_raw", "union_strict": "bray_union_strict",
     "null_sample": "null_sample_bray_spearman_union_strict_mean", "null_feature": "null_feature_bray_spearman_union_strict_mean", "null_mean": "null_mean_bray_spearman_union_strict_mean"},
    {"name": "procrustes_aitchison", "intersection": "intersection_procrustes_aitchison", "union_raw": "procrustes_aitchison_raw", "union_strict": "procrustes_aitchison_strict",
     "null_sample": "null_sample_procrustes_aitchison_union_strict_mean", "null_feature": "null_feature_procrustes_aitchison_union_strict_mean", "null_mean": "null_mean_procrustes_aitchison_union_strict_mean"},
    {"name": "procrustes_bray", "intersection": "intersection_procrustes_bray", "union_raw": "procrustes_bray_raw", "union_strict": "procrustes_bray_strict",
     "null_sample": "null_sample_procrustes_bray_union_strict_mean", "null_feature": "null_feature_procrustes_bray_union_strict_mean", "null_mean": "null_mean_procrustes_bray_union_strict_mean"},
    {"name": "sample_spearman_tss", "intersection": "sample_spearman_tss_intersection", "union_raw": "sample_spearman_tss_union_raw", "union_strict": "sample_spearman_tss_union_strict",
     "null_sample": "null_sample_sample_spearman_tss_union_strict_mean", "null_feature": "null_feature_sample_spearman_tss_union_strict_mean", "null_mean": "null_mean_sample_spearman_tss_union_strict_mean"},
    {"name": "sample_spearman_clr", "intersection": "sample_spearman_clr_intersection", "union_raw": "sample_spearman_clr_union_raw", "union_strict": "sample_spearman_clr_union_strict",
     "null_sample": "null_sample_sample_spearman_clr_union_strict_mean", "null_feature": "null_feature_sample_spearman_clr_union_strict_mean", "null_mean": "null_mean_sample_spearman_clr_union_strict_mean"},
    {"name": "soft_precision", "intersection": "intersection_soft_precision", "union_raw": "soft_precision_union_raw", "union_strict": "soft_precision",
     "null_sample": "null_sample_soft_precision_union_strict_mean", "null_feature": "null_feature_soft_precision_union_strict_mean", "null_mean": "null_mean_soft_precision_union_strict_mean"},
    {"name": "soft_recall", "intersection": "intersection_soft_recall", "union_raw": "soft_recall_union_raw", "union_strict": "soft_recall",
     "null_sample": "null_sample_soft_recall_union_strict_mean", "null_feature": "null_feature_soft_recall_union_strict_mean", "null_mean": "null_mean_soft_recall_union_strict_mean"},
    {"name": "soft_f1", "intersection": "intersection_soft_f1", "union_raw": "soft_f1_union_raw", "union_strict": "soft_f1",
     "null_sample": "null_sample_soft_f1_union_strict_mean", "null_feature": "null_feature_soft_f1_union_strict_mean", "null_mean": "null_mean_soft_f1_union_strict_mean"},
    {"name": "wclr_mse", "intersection": "intersection_wclr_mse", "union_raw": "wclr_mse_union_raw", "union_strict": "wclr_mse",
     "null_sample": "null_sample_wclr_mse_union_strict_mean", "null_feature": "null_feature_wclr_mse_union_strict_mean", "null_mean": "null_mean_wclr_mse_union_strict_mean"},
    {"name": "jsd", "intersection": "intersection_jsd", "union_raw": "jsd_union_raw", "union_strict": "jsd",
     "null_sample": "null_sample_jsd_union_strict_mean", "null_feature": "null_feature_jsd_union_strict_mean", "null_mean": "null_mean_jsd_union_strict_mean"},
    {"name": "pathway_rmse", "intersection": "intersection_pathway_rmse", "union_raw": "pathway_rmse_union_raw", "union_strict": "pathway_rmse",
     "null_sample": "null_sample_pathway_rmse_union_strict_mean", "null_feature": "null_feature_pathway_rmse_union_strict_mean", "null_mean": "null_mean_pathway_rmse_union_strict_mean"},
]


def _get(d, key):
    if d is None or key is None:
        return None
    return d.get(key)

rows = []
for spec in metrics_spec:
    name = spec["name"]
    model_inter = _get(metrics_oof, spec["intersection"])
    model_raw = _get(metrics_oof, spec["union_raw"])
    model_strict = _get(metrics_oof, spec["union_strict"])
    model_null_sample = _get(metrics_oof, spec["null_sample"])
    model_null_feature = _get(metrics_oof, spec["null_feature"])
    model_null_mean = _get(metrics_oof, spec["null_mean"])
    pic_inter = _get(picrust_metrics, spec["intersection"])
    pic_raw = _get(picrust_metrics, spec["union_raw"])
    pic_strict = _get(picrust_metrics, spec["union_strict"])
    pic_null_sample = _get(picrust_metrics, spec["null_sample"])
    pic_null_feature = _get(picrust_metrics, spec["null_feature"])
    pic_null_mean = _get(picrust_metrics, spec["null_mean"])
    rows.append({
        "metric": name,
        "model_intersection": model_inter,
        "model_union_raw": model_raw,
        "model_union_strict": model_strict,
        "model_null_sample_mean": model_null_sample,
        "model_null_feature_mean": model_null_feature,
        "model_null_mean": model_null_mean,
        "picrust_intersection": pic_inter,
        "picrust_union_raw": pic_raw,
        "picrust_union_strict": pic_strict,
        "picrust_null_sample_mean": pic_null_sample,
        "picrust_null_feature_mean": pic_null_feature,
        "picrust_null_mean": pic_null_mean,
        "delta_intersection": (None if model_inter is None or pic_inter is None else model_inter - pic_inter),
        "delta_union_raw": (None if model_raw is None or pic_raw is None else model_raw - pic_raw),
        "delta_union_strict": (None if model_strict is None or pic_strict is None else model_strict - pic_strict),
    })

compare_table = pd.DataFrame(rows)
#save the compare_table to tsv:
compare_table.to_csv(results_dir / 'comparison_table_all_metrics.tsv', sep='	', index=False)
compare_table
# Out:
#                   metric  model_intersection  model_union_raw  \
# 0            dm_spearman            0.558163         0.558163
# 1          bray_spearman            0.487632         0.487632
# 2   procrustes_aitchison            0.618597         0.618597
# 3        procrustes_bray            0.567916         0.567916
# 4    sample_spearman_tss            0.922506         0.922506
# 5    sample_spearman_clr            0.922506         0.922506
# 6         soft_precision            0.845472         0.845472
# 7            soft_recall            0.964634         0.964634
# 8                soft_f1            0.899707         0.899707
# 9               wclr_mse            1.697014         1.697014
# 10                   jsd            0.008878         0.008878
# 11          pathway_rmse                 NaN              NaN
#
#     model_union_strict  model_null_sample_mean  model_null_feature_mean  \
# 0             0.931120                0.019833                 0.928792
# 1             0.872796                0.000616                 0.858931
# 2             0.786843                0.055199                 0.769055
# 3             0.755678                0.043409                 0.691596
# 4             0.868482                0.610632                -0.000641
# 5             0.868482                0.610632                -0.000641
# 6             0.878540                0.709191                 0.009472
# 7             0.865299                0.684264                 0.009722
# 8             0.864475                0.560564                 0.009514
# 9             5.823664               23.821242                21.474063
# 10            0.060685                0.187336                 0.687352
# 11                 NaN                     NaN                      NaN
#
#     model_null_mean  picrust_intersection  picrust_union_raw  \
# 0          0.673536              0.661000           0.636370
# 1          0.707923              0.633150           0.643837
# 2          0.533111              0.590978           0.566101
# 3          0.535869              0.605748           0.611957
# 4          0.153158              0.761290           0.685211
# 5          0.153158              0.761290           0.685211
# 6          0.610081              0.778287           0.726012
# 7          0.849325              0.892227           0.763806
# 8          0.663170              0.830306           0.743011
# 9         15.676549              7.786870           8.552300
# 10         0.115677              0.116337           0.130684
# 11              NaN                   NaN                NaN
#
#     picrust_union_strict  picrust_null_sample_mean  picrust_null_feature_mean  \
# 0               0.878948                 -0.004247                   0.877650
# 1               0.802656                  0.001191                   0.791594
# 2               0.754831                  0.056272                   0.738199
# 3               0.675473                  0.051077                   0.657507
# 4               0.419909                  0.381755                  -0.000900
# 5               0.419909                  0.381755                  -0.000900
# 6               0.579690                  0.542961                   0.007711
# 7               0.312665                  0.360956                   0.003862
# 8               0.399805                  0.338933                   0.005097
# 9              17.173392                 20.914259                  20.433478
# 10              0.315503                  0.344720                   0.689942
# 11                   NaN                       NaN                        NaN
#
#     picrust_null_mean  delta_intersection  delta_union_raw  delta_union_strict
# 0            0.714177           -0.102836        -0.078206            0.052172
# 1            0.733863           -0.145517        -0.156204            0.070141
# 2            0.546548            0.027620         0.052496            0.032013
# 3            0.545963           -0.037832        -0.044041            0.080205
# 4            0.143501            0.161216         0.237294            0.448573
# 5            0.143501            0.161216         0.237294            0.448573
# 6            0.631666            0.067185         0.119460            0.298850
# 7            0.836270            0.072406         0.200828            0.552634
# 8            0.674176            0.069401         0.156697            0.464669
# 9           15.006946           -6.089856        -6.855285          -11.349728
# 10           0.114633           -0.107459        -0.121806           -0.254818
# 11                NaN                 NaN              NaN                 NaN

# %% [markdown]
# Metric definitions (higher is better unless noted):
#
#   - dm_spearman: Spearman correlation between upper triangles of Aitchison distance matrices
#     (CLR space). Measures how well sample–sample relationships are preserved.
#
#   - bray_spearman: Spearman correlation between upper triangles of Bray–Curtis distance matrices
#     (TSS space). Also measures sample–sample structure, but in Bray–Curtis space.
#
#   - procrustes_aitchison_strict: Procrustes similarity between ordinations of Aitchison distance matrices
#     (CLR space). Higher means closer geometric alignment of the two ordinations.
#
#   - procrustes_bray_strict: Procrustes similarity between ordinations of Bray–Curtis distance matrices
#     (TSS space). Higher means closer geometric alignment.
#
#   - soft_precision / soft_recall / soft_f1: Thresholded precision/recall/F1 on KO presence,
#     computed in TSS space using the chosen threshold and weighting scheme.
#     - soft_precision = TP / (TP + FP), meaning of all predicted present KOs, how many are truly present.
#     - soft_recall = TP / (TP + FN), meaning of all truly present KOs, how many are predicted present.
#     - soft_f1 = 2 * (soft_precision * soft_recall) / (soft_precision + soft_recall) (harmonic mean of precision and recall).
#
#   - wclr_mse: Weighted MSE in CLR space (lower is better). Weights emphasize more stable features.
#
#   - jsd: Jensen–Shannon divergence between TSS profiles (lower is better).
#
#   - pathway_rmse: RMSE after aggregating KOs to pathways/superclasses (lower is better).
#
#   - model_null_sample_mean = null baseline from shuffling samples (breaks sample alignment, preserves per‑sample feature distribution).
#   - model_null_feature_mean = null baseline from shuffling features (breaks feature alignment, preserves per‑feature sample distribution).
#   - model_null_mean = null baseline from a mean profile + noise (global average baseline).

# %%
# Visualize deltas (positive = model better than PICRUSt2 for correlation metrics)
#multiply all except wclr_mse, pathway_rmse and jsd by 100 (for percentage):
compare_table_for_plotting = compare_table.copy()
#set index to metric:
compare_table_for_plotting = compare_table_for_plotting.set_index('metric')
#multiply each row except wclr_mse by 100:

for idx in compare_table_for_plotting.index:
    if idx != 'wclr_mse' and idx != 'pathway_rmse' and idx != 'jsd':
        compare_table_for_plotting.loc[idx] = compare_table_for_plotting.loc[idx]* 100

compare_table_for_plotting
# Out:
#                       model_intersection  model_union_raw  model_union_strict  \
# metric
# dm_spearman                    55.816349        55.816349           93.111991
# bray_spearman                  48.763249        48.763249           87.279632
# procrustes_aitchison           61.859727        61.859727           78.684322
# procrustes_bray                56.791581        56.791581           75.567796
# sample_spearman_tss            92.250563        92.250563           86.848182
# sample_spearman_clr            92.250566        92.250564           86.848182
# soft_precision                 84.547204        84.547204           87.853951
# soft_recall                    96.463357        96.463357           86.529895
# soft_f1                        89.970744        89.970744           86.447463
# wclr_mse                        1.697014         1.697014            5.823664
# jsd                             0.008878         0.008878            0.060685
# pathway_rmse                         NaN              NaN                 NaN
#
#                       model_null_sample_mean  model_null_feature_mean  \
# metric
# dm_spearman                         1.983311                92.879201
# bray_spearman                       0.061623                85.893128
# procrustes_aitchison                5.519856                76.905542
# procrustes_bray                     4.340936                69.159576
# sample_spearman_tss                61.063242                -0.064118
# sample_spearman_clr                61.063242                -0.064118
# soft_precision                     70.919119                 0.947247
# soft_recall                        68.426413                 0.972150
# soft_f1                            56.056419                 0.951357
# wclr_mse                           23.821242                21.474063
# jsd                                 0.187336                 0.687352
# pathway_rmse                             NaN                      NaN
#
#                       model_null_mean  picrust_intersection  \
# metric
# dm_spearman                 67.353563             66.099958
# bray_spearman               70.792304             63.314955
# procrustes_aitchison        53.311075             59.097764
# procrustes_bray             53.586924             60.574774
# sample_spearman_tss         15.315809             76.129005
# sample_spearman_clr         15.315809             76.129010
# soft_precision              61.008060             77.828662
# soft_recall                 84.932487             89.222722
# soft_f1                     66.317025             83.030648
# wclr_mse                    15.676549              7.786870
# jsd                          0.115677              0.116337
# pathway_rmse                      NaN                   NaN
#
#                       picrust_union_raw  picrust_union_strict  \
# metric
# dm_spearman                   63.636980             87.894753
# bray_spearman                 64.383653             80.265552
# procrustes_aitchison          56.610116             75.483063
# procrustes_bray               61.195691             67.547292
# sample_spearman_tss           68.521131             41.990905
# sample_spearman_clr           68.521133             41.990905
# soft_precision                72.601158             57.968981
# soft_recall                   76.380570             31.266473
# soft_f1                       74.301054             39.980547
# wclr_mse                       8.552300             17.173392
# jsd                            0.130684              0.315503
# pathway_rmse                        NaN                   NaN
#
#                       picrust_null_sample_mean  picrust_null_feature_mean  \
# metric
# dm_spearman                          -0.424729                  87.765035
# bray_spearman                         0.119130                  79.159432
# procrustes_aitchison                  5.627220                  73.819925
# procrustes_bray                       5.107697                  65.750692
# sample_spearman_tss                  38.175513                  -0.090033
# sample_spearman_clr                  38.175513                  -0.090033
# soft_precision                       54.296065                   0.771094
# soft_recall                          36.095574                   0.386219
# soft_f1                              33.893309                   0.509749
# wclr_mse                             20.914259                  20.433478
# jsd                                   0.344720                   0.689942
# pathway_rmse                               NaN                        NaN
#
#                       picrust_null_mean  delta_intersection  delta_union_raw  \
# metric
# dm_spearman                   71.417691          -10.283609        -7.820631
# bray_spearman                 73.386332          -14.551706       -15.620404
# procrustes_aitchison          54.654776            2.761963         5.249611
# procrustes_bray               54.596329           -3.783193        -4.404110
# sample_spearman_tss           14.350069           16.121558        23.729432
# sample_spearman_clr           14.350069           16.121556        23.729431
# soft_precision                63.166565            6.718542        11.946046
# soft_recall                   83.627043            7.240635        20.082787
# soft_f1                       67.417569            6.940097        15.669690
# wclr_mse                      15.006946           -6.089856        -6.855285
# jsd                            0.114633           -0.107459        -0.121806
# pathway_rmse                        NaN                 NaN              NaN
#
#                       delta_union_strict
# metric
# dm_spearman                     5.217239
# bray_spearman                   7.014080
# procrustes_aitchison            3.201260
# procrustes_bray                 8.020505
# sample_spearman_tss            44.857276
# sample_spearman_clr            44.857276
# soft_precision                 29.884971
# soft_recall                    55.263422
# soft_f1                        46.466916
# wclr_mse                      -11.349728
# jsd                            -0.254818
# pathway_rmse                         NaN

# %%
#load some colors for plotting
hex_colors = ['#240E31FF', '#CB6BCEFF', '#468892FF', '#74F3D3FF',
              '#751C6DFF', '#FDC067FF', '#AC9ECEFF', '#6EC5ABFF']

# %%
results_dir
# Out:
# PosixPath('/Users/meyeanni/Desktop/git_sourdough/Intelligrate/results/primates_ecs')

# %% [markdown]
# now we'll compare correspondence between kNN predictability and PICRUSt2 vs. kNN improvement over PICRUSt2

# %%
#make a bar plot for dm_spearman for model_intersection, model_union_raw, model_union_strict, model_null_mean, same for picrust:
import matplotlib.pyplot as plt
labels = ['Null', 'Intersection', 'Union_raw', 'Union_strict']
metrics = ['dm_spearman', 'sample_spearman_clr', 'sample_spearman_tss', 'soft_precision', 'soft_recall', 'soft_f1', 'wclr_mse', 'jsd', 'pathway_rmse']
for metric in metrics:
    model_values = [
        compare_table_for_plotting.loc[metric, 'model_null_mean'],
        compare_table_for_plotting.loc[metric, 'model_intersection'],
        compare_table_for_plotting.loc[metric, 'model_union_raw'],
        compare_table_for_plotting.loc[metric, 'model_union_strict'],
    ]
    picrust_values = [
        compare_table_for_plotting.loc[metric, 'picrust_null_mean'],
        compare_table_for_plotting.loc[metric, 'picrust_intersection'],
        compare_table_for_plotting.loc[metric, 'picrust_union_raw'],
        compare_table_for_plotting.loc[metric, 'picrust_union_strict'],
    ]
    x = range(len(labels))
    width = 0.35  # the width of the bars

    fig, ax = plt.subplots()
    #set figure size:
    fig.set_size_inches(7, 3.5)
    rects1 = ax.bar([p - width/2 for p in x], model_values, width, label='kNN-model', color=hex_colors[4], alpha=0.8)
    rects2 = ax.bar([p + width/2 for p in x], picrust_values, width, label='PICRUSt2', color=hex_colors[5], alpha=0.8)
    # Add some text for labels, title and custom x-axis tick labels, etc.
    ax.set_ylabel(f"{metric}", fontsize=14)
    ax.set_title(f'Comparison of kNN-model vs PICRUSt2 {metric} primates_ecs', fontsize=16, pad=15)
    ax.set_xticks(x)
    ax.set_xticklabels(labels, fontsize=14, rotation=45, ha='right')
    #set y tick labels also to fontsize 14:
    ax.tick_params(axis='y', labelsize=14)
    ax.legend(fontsize=14, frameon=True, bbox_to_anchor=(1.05, 1), loc='upper left')
    #add the values on top of the bars:
    def autolabel(rects):
        """Attach a text label above each bar in *rects*, displaying its height."""
        for rect in rects:
            height = rect.get_height()
            if height > 10:
                ax.annotate(f'{height:.1f}',
                            xy=(rect.get_x() + rect.get_width() / 2, height),
                            xytext=(0, 3),  # 3 points vertical offset
                            textcoords="offset points",
                            ha='center', va='bottom', fontsize=12)
            else:
                ax.annotate(f'{height:.2f}',
                            xy=(rect.get_x() + rect.get_width() / 2, height),
                            xytext=(0, 3),  # 3 points vertical offset
                            textcoords="offset points",
                            ha='center', va='bottom', fontsize=12)
  

    autolabel(rects1)
    autolabel(rects2)
    #despine:
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    fig.tight_layout()
    #save the figure as pdf:
    figure_path = results_dir / f'comparison_kNN_picrust2_{metric}.pdf'
    plt.savefig(figure_path, format='pdf', bbox_inches='tight', dpi=300)
    plt.show()

# %% [markdown]
# ### Next: Sample-wise Spearman correlations (truth vs prediction) with null baselines
# This shows per-sample correlations across KOs in TSS and CLR space, plus null baselines from shuffled samples and shuffled features.

# %%
from intelligrate.extrapolate.metrics import (
      _pairwise_union_mats_tss,
      _pairwise_intersection_mats_tss,
      samplewise_spearman,
  )
from intelligrate.extrapolate.transforms import clr_rows
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

def _sample_spearman_dist(truth_tpm, pred_tss, *, pseudocount, detect_threshold, mode="union_strict"):
      if mode == "intersection":
          truth_tss, pred_tss = _pairwise_intersection_mats_tss(truth_tpm, pred_tss, detect_threshold=0.0)
      elif mode == "union_raw":
          truth_tss, pred_tss = _pairwise_union_mats_tss(truth_tpm, pred_tss, detect_threshold=0.0, fillna_zero=True)
      else:  # union_strict
          truth_tss, pred_tss = _pairwise_union_mats_tss(truth_tpm, pred_tss, detect_threshold=detect_threshold, fillna_zero=True)

      truth_clr = clr_rows(truth_tss, pseudocount=pseudocount)
      pred_clr = clr_rows(pred_tss, pseudocount=pseudocount)
      good = truth_clr.notna().all(axis=1) & pred_clr.notna().all(axis=1)
      truth_tss, pred_tss = truth_tss.loc[good], pred_tss.loc[good]
      truth_clr, pred_clr = truth_clr.loc[good], pred_clr.loc[good]

      tss = samplewise_spearman(truth_tss, pred_tss)
      clr = samplewise_spearman(truth_clr, pred_clr)
      return tss, clr

def _null_sample_spearman_dist(truth_tpm, pred_tss, *, pseudocount, detect_threshold, n=50, seed=0):
      rng = np.random.default_rng(seed)
      truth_tss, pred_tss = _pairwise_union_mats_tss(truth_tpm, pred_tss, detect_threshold=detect_threshold, fillna_zero=True)
      truth_clr = clr_rows(truth_tss, pseudocount=pseudocount)
      pred_clr = clr_rows(pred_tss, pseudocount=pseudocount)
      good = truth_clr.notna().all(axis=1) & pred_clr.notna().all(axis=1)
      truth_tss, pred_tss = truth_tss.loc[good], pred_tss.loc[good]
      truth_clr, pred_clr = truth_clr.loc[good], pred_clr.loc[good]

      pred_tss_arr = pred_tss.to_numpy(float)
      pred_clr_arr = pred_clr.to_numpy(float)
      tss_vals, clr_vals = [], []
      for _ in range(int(n)):
          perm = rng.permutation(pred_tss_arr.shape[0])
          pred_tss_perm = pd.DataFrame(pred_tss_arr[perm, :], index=truth_tss.index, columns=truth_tss.columns)
          pred_clr_perm = pd.DataFrame(pred_clr_arr[perm, :], index=truth_clr.index, columns=truth_clr.columns)
          tss_vals.append(samplewise_spearman(truth_tss, pred_tss_perm))
          clr_vals.append(samplewise_spearman(truth_clr, pred_clr_perm))
      return pd.concat(tss_vals, axis=0), pd.concat(clr_vals, axis=0)

def _null_feature_spearman_dist(truth_tpm, pred_tss, *, pseudocount, detect_threshold, n=50, seed=1):
      rng = np.random.default_rng(seed)
      truth_tss, pred_tss = _pairwise_union_mats_tss(truth_tpm, pred_tss, detect_threshold=detect_threshold, fillna_zero=True)
      truth_clr = clr_rows(truth_tss, pseudocount=pseudocount)
      pred_clr = clr_rows(pred_tss, pseudocount=pseudocount)
      good = truth_clr.notna().all(axis=1) & pred_clr.notna().all(axis=1)
      truth_tss, pred_tss = truth_tss.loc[good], pred_tss.loc[good]
      truth_clr, pred_clr = truth_clr.loc[good], pred_clr.loc[good]

      pred_tss_arr = pred_tss.to_numpy(float)
      pred_clr_arr = pred_clr.to_numpy(float)
      tss_vals, clr_vals = [], []
      for _ in range(int(n)):
          perm = rng.permutation(pred_tss_arr.shape[1])
          pred_tss_feat = pd.DataFrame(pred_tss_arr[:, perm], index=truth_tss.index, columns=truth_tss.columns)
          pred_clr_feat = pd.DataFrame(pred_clr_arr[:, perm], index=truth_clr.index, columns=truth_clr.columns)
          tss_vals.append(samplewise_spearman(truth_tss, pred_tss_feat))
          clr_vals.append(samplewise_spearman(truth_clr, pred_clr_feat))
      return pd.concat(tss_vals, axis=0), pd.concat(clr_vals, axis=0)

def _null_mean_spearman_dist(truth_tpm, pred_tss, *, pseudocount, detect_threshold, n=50, seed=2, noise=0.01):
      rng = np.random.default_rng(seed)
      truth_tss, pred_tss = _pairwise_union_mats_tss(truth_tpm, pred_tss, detect_threshold=detect_threshold, fillna_zero=True)
      truth_clr = clr_rows(truth_tss, pseudocount=pseudocount)
      pred_clr = clr_rows(pred_tss, pseudocount=pseudocount)
      good = truth_clr.notna().all(axis=1) & pred_clr.notna().all(axis=1)
      truth_tss, pred_tss = truth_tss.loc[good], pred_tss.loc[good]
      truth_clr, pred_clr = truth_clr.loc[good], pred_clr.loc[good]

      mu_tss = truth_tss.mean(axis=0).to_numpy(float)
      mu_clr = truth_clr.mean(axis=0).to_numpy(float)
      tss_vals, clr_vals = [], []
      for _ in range(int(n)):
          noise_tss = rng.normal(0.0, noise, size=pred_tss.shape)
          noise_clr = rng.normal(0.0, noise, size=pred_clr.shape)
          pred_tss_mean = pd.DataFrame(np.clip(mu_tss[None, :] + noise_tss, 0.0, None), index=truth_tss.index, columns=truth_tss.columns)
          pred_clr_mean = pd.DataFrame(mu_clr[None, :] + noise_clr, index=truth_clr.index, columns=truth_clr.columns)
          tss_vals.append(samplewise_spearman(truth_tss, pred_tss_mean))
          clr_vals.append(samplewise_spearman(truth_clr, pred_clr_mean))
      return pd.concat(tss_vals, axis=0), pd.concat(clr_vals, axis=0)

  # --- Compute distributions for strict / raw / intersection ---
tss_model, clr_model = _sample_spearman_dist(Y, oof_fixed_tss_aligned, pseudocount=model_cfg["pseudocount_y"], detect_threshold=y_detect_threshold,
  mode="union_strict")
tss_model_raw, clr_model_raw = _sample_spearman_dist(Y, oof_fixed_tss_aligned, pseudocount=model_cfg["pseudocount_y"], detect_threshold=y_detect_threshold,
  mode="union_raw")
tss_model_int, clr_model_int = _sample_spearman_dist(Y, oof_fixed_tss_aligned, pseudocount=model_cfg["pseudocount_y"], detect_threshold=y_detect_threshold,
  mode="intersection")

tss_null, clr_null = _null_sample_spearman_dist(Y, oof_fixed_tss_aligned, pseudocount=model_cfg["pseudocount_y"], detect_threshold=y_detect_threshold, n=50,
  seed=0)
tss_feat_null, clr_feat_null = _null_feature_spearman_dist(Y, oof_fixed_tss_aligned, pseudocount=model_cfg["pseudocount_y"], detect_threshold=y_detect_threshold,
  n=50, seed=0)
tss_mean_null, clr_mean_null = _null_mean_spearman_dist(Y, oof_fixed_tss_aligned, pseudocount=model_cfg["pseudocount_y"], detect_threshold=y_detect_threshold,
  n=50, seed=0, noise=0.0001)

tss_pic = clr_pic = None
if picrust_metrics is not None:
      tss_pic, clr_pic = _sample_spearman_dist(Y, picrust, pseudocount=model_cfg["pseudocount_y"], detect_threshold=y_detect_threshold, mode="union_strict")
      #also for raw and intersection:
      tss_pic_raw, clr_pic_raw = _sample_spearman_dist(Y, picrust, pseudocount=model_cfg["pseudocount_y"], detect_threshold=y_detect_threshold, mode="union_raw")
      tss_pic_int, clr_pic_int = _sample_spearman_dist(Y, picrust, pseudocount=model_cfg["pseudocount_y"], detect_threshold=y_detect_threshold, mode="intersection")

      #and also nulls for picrust:
      tss_pic_null, clr_pic_null = _null_mean_spearman_dist(Y, picrust, pseudocount=model_cfg["pseudocount_y"], detect_threshold=y_detect_threshold, n=50,
        seed=0, noise=0.0001)

# %%
#now, we aggregate all the metrics to plot the distributions:

tss_map = {
      "kNN_strict": tss_model,
      "kNN_raw": tss_model_raw,
      "kNN_intersection": tss_model_int,
      # "null_sample": tss_null,
      # "null_feature": tss_feat_null,
      "kNN_null_mean": tss_mean_null,
  }
if tss_pic is not None:
      tss_map["picrust2_strict"] = tss_pic
      tss_map['picrust2_raw'] = tss_pic_raw
      tss_map['picrust2_intersection'] = tss_pic_int
      tss_map['picrust2_null_mean'] = tss_pic_null

clr_map = {
      "kNN_strict": clr_model,
      "kNN_raw": clr_model_raw,
      "kNN_intersection": clr_model_int,
      # "null_sample": clr_null,
      # "null_feature": clr_feat_null,
      "kNN_null_mean": clr_mean_null,
  }
if clr_pic is not None:
      clr_map["picrust2_strict"] = clr_pic
      clr_map['picrust2_raw'] = clr_pic_raw
      clr_map['picrust2_intersection'] = clr_pic_int
      clr_map['picrust2_null_mean'] = clr_pic_null

#rearrange the order to plot:
map_order = [
      "kNN_null_mean",
      "picrust2_null_mean",
      "kNN_intersection",
      "picrust2_intersection",
      "kNN_raw",
      "picrust2_raw",
      "kNN_strict",
      "picrust2_strict",
  ]  
tss_map = {k: tss_map[k] for k in map_order if k in tss_map}
clr_map = {k: clr_map[k] for k in map_order if k in clr_map}

# %% [markdown]
# define all the plotting utilities:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import wilcoxon
from statsmodels.stats.multitest import multipletests
from itertools import combinations

def pairwise_wilcoxon_cld(data_map, alpha=0.05, zero_method="wilcox"):
      """
      Paired Wilcoxon signed-rank with BH correction + CLD.
      data_map: dict[label -> pd.Series with SAME index].
      """
      labels = list(data_map.keys())
      # align indices
      common = None
      for k, v in data_map.items():
          if common is None:
              common = v.index
          else:
              common = common.intersection(v.index)
      aligned = {k: data_map[k].loc[common].astype(float) for k in labels}

      rows = []
      for a, b in combinations(labels, 2):
          x, y = aligned[a], aligned[b]
          # drop NaNs pairwise
          m = np.isfinite(x) & np.isfinite(y)
          if m.sum() < 10:
              p = np.nan
          else:
              p = wilcoxon(x[m], y[m], zero_method=zero_method).pvalue
          rows.append((a, b, p))
      p_df = pd.DataFrame(rows, columns=["A", "B", "pval"])

      # FDR correction
      pvals = p_df["pval"].to_numpy()
      mask = np.isfinite(pvals)
      adj = np.full_like(pvals, np.nan, dtype=float)
      if mask.sum() > 0:
          adj[mask] = multipletests(pvals[mask], alpha=alpha, method="fdr_bh")[1]
      p_df["p_adj"] = adj

      # significance matrix
      sig = {a: {b: False for b in labels} for a in labels}
      for _, row in p_df.iterrows():
          if np.isfinite(row["p_adj"]) and row["p_adj"] < alpha:
              sig[row["A"]][row["B"]] = True
              sig[row["B"]][row["A"]] = True

      # greedy CLD
      cld = {k: "" for k in labels}
      letters = []
      for label in labels:
          placed = False
          for letter in letters:
              conflict = False
              for other, ltr in cld.items():
                  if ltr == letter and sig[label][other]:
                      conflict = True
                      break
              if not conflict:
                  cld[label] = letter
                  placed = True
                  break
          if not placed:
              new_letter = chr(ord("a") + len(letters))
              letters.append(new_letter)
              cld[label] = new_letter

      return cld, p_df
def to_sample_mean(v, sample_index, sample_col="sample", value_col="value"):
    if isinstance(v, pd.Series):
        # if Series is already sample-indexed (possibly with repeats), groupby works too
        s = pd.to_numeric(v, errors="coerce")
        out = s.groupby(level=0).mean()
        return out.reindex(sample_index)

    if isinstance(v, pd.DataFrame):
        if sample_col in v.columns and value_col in v.columns:
            out = v.groupby(sample_col, as_index=True)[value_col].mean()
            return out.reindex(sample_index)

        # If it is wide (index=samples, columns=replicates), average across columns
        if v.index.equals(sample_index):
            return v.apply(pd.to_numeric, errors="coerce").mean(axis=1)

    raise ValueError("Cannot compute per-sample mean: no sample IDs found.")
  
sample_index = tss_model.index

tss_map_aligned = {}
for k, v in tss_map.items():
    if v is None:
        continue
    tss_map_aligned[k] = to_sample_mean(v, sample_index, sample_col="sample", value_col="spearman")

clr_map_aligned = {}
for k, v in clr_map.items():
    if v is None:
        continue
    clr_map_aligned[k] = to_sample_mean(v, sample_index, sample_col="sample", value_col="spearman")


def _plot_violin_with_cld_paired(
      data_map,
      title,
      alpha=0.05,
      colors=None,   # dict label -> color
      dot_alpha=0.5,
      letter_offset=0.02,
  ):
      labels = list(data_map.keys())
      data = [data_map[k].dropna().to_numpy(float) for k in labels]

      fig, ax = plt.subplots(figsize=(5, 4.5))
      parts = ax.violinplot(data, showmeans=True, showextrema=False)

      for i, body in enumerate(parts['bodies']):
                label = labels[i]
                c = colors.get(label, "#999999") if colors else "#999999"
                body.set_facecolor(c)
                body.set_edgecolor("none")
                body.set_alpha(0.3)

      # Set color black for mean lines:
      if 'cmeans' in parts:
          parts['cmeans'].set_color('black')
          parts['cmeans'].set_linewidth(1.5)

        # Dots with matching color
      for i, vals in enumerate(data, start=1):
            label = labels[i-1]
            c = colors.get(label, "#666666") if colors else "#666666"
            x = np.random.normal(i, 0.04, size=len(vals))
            ax.scatter(x, vals, s=8, alpha=dot_alpha, color=c)

      ax.set_xticks(range(1, len(labels) + 1))
      ax.set_xticklabels(labels, rotation=45, fontsize=14, ha='right')
      ax.tick_params(axis='y', labelsize=14)
      ax.set_ylabel("sample-wise Spearman", fontsize=14)
      ax.set_ylim(0.0, 1.1)
      ax.set_title(title, pad=15, fontsize=16)

      cld, p_df = pairwise_wilcoxon_cld(data_map, alpha=alpha)

      # Place CLD letters right above each violin
      for i, lab in enumerate(labels, start=1):
          vals = data[i-1]
          if len(vals) == 0:
              continue
          y = np.nanmax(vals) + letter_offset
          ax.text(i, y, cld.get(lab, ""), ha="center", va="bottom", fontsize=14)
      #despine:
      ax.spines['top'].set_visible(False)
      ax.spines['right'].set_visible(False)  
      fig.tight_layout()
      #save as pdf, with title in name:
      figure_path = results_dir / f'violin_{title.replace(" ", "_").lower()}.pdf'
      plt.savefig(figure_path, format='pdf', bbox_inches='tight', dpi=300)
      plt.show()
      return cld, p_df

  #Example color mapping (distinct model vs picrust):

colors = {
      "kNN_strict": hex_colors[4],
      "kNN_raw": hex_colors[4],
      "kNN_intersection": hex_colors[4],
      "picrust2_strict": hex_colors[5],
      "picrust2_raw": hex_colors[5],
      "picrust2_intersection": hex_colors[5],
      "kNN_null_mean": hex_colors[4],
      "picrust2_null_mean": hex_colors[5],
  }

cld_tss, p_tss = _plot_violin_with_cld_paired(tss_map_aligned, "TSS sample-wise Spearman primates_ecs",
  colors=colors)
cld_clr, p_clr = _plot_violin_with_cld_paired(clr_map_aligned, "CLR sample-wise Spearman primates_ecs",
  colors=colors)
# Out:
# /Users/meyeanni/miniconda3/envs/network-viz/lib/python3.10/site-packages/scipy/stats/_wilcoxon.py:172: RuntimeWarning: invalid value encountered in scalar divide
#   z = (r_plus - mn) / se
# /Users/meyeanni/miniconda3/envs/network-viz/lib/python3.10/site-packages/scipy/stats/_wilcoxon.py:172: RuntimeWarning: invalid value encountered in scalar divide
#   z = (r_plus - mn) / se

# %% [markdown]
# ## Interpreting outputs
# - `results/oof_clr.tsv`, `results/oof_tss.tsv`: out-of-fold predictions from nested CV
# - `results/folds.tsv`: per-fold metrics + selected hyperparameters
# - `results/summary.json` / `results/summary.tsv`: overall metrics
# - `results/embed.joblib`: fitted embedding for k-mers
# - `results/model.joblib`: final model artifact
# - `results/pred_full.*`: predictions for all samples
# - `results/pred_paired.metrics.tsv`: metrics when truth is provided
